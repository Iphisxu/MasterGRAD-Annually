# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

from matplotlib import rcParams
config = {
    "font.family":'Times New Roman',
    "mathtext.fontset":'stix',
    "font.serif": ['SimSun'],
}
rcParams.update(config)

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append('../src/')

# %% [markdown]
# # 全年

# %%
df = pd.read_excel('F:/Data/Graduation/OBS_Seasons/O3_years.xlsx',index_col=0)
mda8 = df.resample('D').max()
mda8.dropna(inplace=True)
mda8['year']=mda8.index.year
mda8
# Out:
#                广州     深圳     珠海     佛山     中山     江门     东莞     惠州     肇庆  \
# datetime
# 2014-05-13   57.0   36.0   48.0   58.0   33.0   60.0   63.0   47.0   81.0
# 2014-05-14   74.0   37.0   41.0   56.0   32.0   34.0   67.0   44.0   72.0
# 2014-05-15   97.0   41.0   51.0   91.0   52.0   43.0   84.0   70.0  110.0
# 2014-05-16   39.0   39.0   51.0   55.0   51.0   36.0   49.0   45.0   84.0
# 2014-05-17   51.0   33.0   40.0   52.0   37.0   30.0   60.0   51.0   66.0
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-05-16  161.0  104.0  132.0  135.0  150.0  131.0  179.0  116.0  108.0
# 2023-05-17   87.0   70.0   91.0   87.0   86.0   82.0   89.0   79.0   89.0
# 2023-05-18  164.0   88.0   87.0  145.0  127.0  121.0  161.0  128.0  131.0
# 2023-05-19  130.0   82.0   84.0  128.0  109.0  104.0  143.0  118.0  168.0
# 2023-05-20  100.0   71.0   70.0   92.0   85.0   73.0   80.0   83.0  103.0
#
#                    avg  year
# datetime
# ...

# %%
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)},font='Times New Roman',)

plt.rcParams['figure.dpi'] = 300
# usepalette = sns.color_palette("Set2", 9)
usepalette = 'viridis'
grid = sns.FacetGrid(mda8, row='year', hue='year', height=0.5,aspect=15,palette=usepalette)
grid.map(sns.kdeplot, "avg", bw_adjust=0.5, clip_on=False, shade=True, alpha=1, linewidth=1.5)
grid.map(sns.kdeplot, "avg", clip_on=False, color="w", lw=2, bw_adjust=0.5,)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color='black', fontsize=13,
            ha="left", va="center", transform=ax.transAxes)
    
grid.map(label, "year")

grid.set(yticks=[])
grid.set(xlabel='O$_3$ ($\mu$$g/m$$^3$)')
grid.set_titles('')
grid.set_ylabels('')
grid.despine(left=True)

plt.subplots_adjust(hspace=-0.3)
plt.show()

# %% [markdown]
# # 七月

# %%
df_jul = pd.read_excel('F:/Data/Graduation/OBS_Seasons/O3_years_jul.xlsx',index_col=0)
mda8_jul = df_jul.resample('D').max()
mda8_jul.dropna(inplace=True)
mda8_jul['year']=mda8_jul.index.year
mda8_jul
# Out:
#                    avg  year
# datetime
# 2014-07-01   48.777778  2014
# 2014-07-02   64.333333  2014
# 2014-07-03   84.555556  2014
# 2014-07-04   85.555556  2014
# 2014-07-05   96.222222  2014
# ...                ...   ...
# 2022-07-27  142.555556  2022
# 2022-07-28  179.555556  2022
# 2022-07-29  175.222222  2022
# 2022-07-30  127.222222  2022
# 2022-07-31  197.333333  2022
#
# [270 rows x 2 columns]

# %%
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)},font='Times New Roman',)

plt.rcParams['figure.dpi'] = 300
# usepalette = sns.color_palette("Set2", 9)
usepalette = 'viridis'
grid = sns.FacetGrid(mda8_jul, row='year', hue='year', height=0.5,aspect=15,palette=usepalette)
grid.map(sns.kdeplot, "avg", bw_adjust=0.5, clip_on=False, shade=True, alpha=1, linewidth=1.5)
grid.map(sns.kdeplot, "avg", clip_on=False, color="w", lw=2, bw_adjust=0.5,)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color='black', fontsize=13,
            ha="left", va="center", transform=ax.transAxes)
    
grid.map(label, "year")

grid.set(yticks=[])
grid.set(xlabel='O$_3$ ($\mu$$g/m$$^3$)')
grid.set_titles('')
grid.set_ylabels('')
grid.despine(left=True)

plt.subplots_adjust(hspace=-0.3)
plt.show()

# %% [markdown]
# # 九月

# %%
df_sep = pd.read_excel('F:/Data/Graduation/OBS_Seasons/O3_years_sep.xlsx',index_col=0)
mda8_sep = df_sep.resample('D').max()
mda8_sep.dropna(inplace=True)
mda8_sep['year']=mda8_sep.index.year
mda8_sep
# Out:
#                    avg  year
# datetime
# 2014-09-01   69.000000  2014
# 2014-09-02  113.777778  2014
# 2014-09-03  137.666667  2014
# 2014-09-04  154.555556  2014
# 2014-09-05  107.777778  2014
# ...                ...   ...
# 2022-09-26  197.222222  2022
# 2022-09-27  133.333333  2022
# 2022-09-28  117.333333  2022
# 2022-09-29   89.333333  2022
# 2022-09-30   58.333333  2022
#
# [270 rows x 2 columns]

# %%
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)},font='Times New Roman',)

plt.rcParams['figure.dpi'] = 300
# usepalette = sns.color_palette("Set2", 9)
usepalette = 'viridis'
grid = sns.FacetGrid(mda8_sep, row='year', hue='year', height=0.5,aspect=15,palette=usepalette)
grid.map(sns.kdeplot, "avg", bw_adjust=0.5, clip_on=False, shade=True, alpha=1, linewidth=1.5)
grid.map(sns.kdeplot, "avg", clip_on=False, color="w", lw=2, bw_adjust=0.5,)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color='black', fontsize=13,
            ha="left", va="center", transform=ax.transAxes)
    
grid.map(label, "year")

grid.set(yticks=[])
grid.set(xlabel='O$_3$ ($\mu$$g/m$$^3$)')
grid.set_titles('')
grid.set_ylabels('')
grid.despine(left=True)

plt.subplots_adjust(hspace=-0.3)
plt.show()

# %% [markdown]
# # 十月

# %%
df_oct = pd.read_excel('F:/Data/Graduation/OBS_Seasons/O3_years_oct.xlsx',index_col=0)
mda8_oct = df_oct.resample('D').max()
mda8_oct.dropna(inplace=True)
mda8_oct['year']=mda8_oct.index.year
mda8_oct
# Out:
#                    avg  year
# datetime
# 2014-10-01  135.222222  2014
# 2014-10-02  151.777778  2014
# 2014-10-03  131.111111  2014
# 2014-10-04  130.444444  2014
# 2014-10-05  161.111111  2014
# ...                ...   ...
# 2022-10-27  181.000000  2022
# 2022-10-28  169.111111  2022
# 2022-10-29  127.888889  2022
# 2022-10-30  110.111111  2022
# 2022-10-31  120.777778  2022
#
# [279 rows x 2 columns]

# %%
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)},font='Times New Roman',)

plt.rcParams['figure.dpi'] = 300
# usepalette = sns.color_palette("Set2", 9)
usepalette = 'viridis'
grid = sns.FacetGrid(mda8_oct, row='year', hue='year', height=0.5,aspect=15,palette=usepalette)
grid.map(sns.kdeplot, "avg", bw_adjust=0.5, clip_on=False, shade=True, alpha=1, linewidth=1.5)
grid.map(sns.kdeplot, "avg", clip_on=False, color="w", lw=2, bw_adjust=0.5,)

def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color='black', fontsize=13,
            ha="left", va="center", transform=ax.transAxes)
    
grid.map(label, "year")

grid.set(yticks=[])
grid.set(xlabel='O$_3$ ($\mu$$g/m$$^3$)')
grid.set_titles('')
grid.set_ylabels('')
grid.despine(left=True)

plt.subplots_adjust(hspace=-0.3)
plt.show()
