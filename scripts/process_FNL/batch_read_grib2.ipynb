# %% [markdown]
# # 毕业论文
# ## 前置数据处理：使用`pygrib`读取FNL
# `Read FNL file Using pygrib`
# ---
# *@author: Evan*\
# *@date: 2023-10-07*

# %%
import pygrib
import numpy as np
import os

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append('../../src/')
from namelist import *

# %%
def read_grib2_files(years, month, day, hour, variable_names, dir):
    # Initialize an array to store data from each year
    yearly_message = {}
    yearly_data = {}

    for year in years:
        # Construct the file name based on the specified pattern
        file_name = f'fnl_{year:04d}{month:02d}{day:02d}_{hour:02d}_00.grib2'
        file_path = os.path.join(dir, file_name)

        # Open the GRIB2 file
        grb = pygrib.open(file_path)

        # Select the variable based on the given name
        messages = grb.select(name=variable_names)

        # Append the data to the yearly_data list
        yearly_message[year] = messages
        yearly_data[year] = [message.values for message in messages]
        # yearly_data.extend([message.values for message in messages])

        # Close the GRIB2 file
        grb.close()

    # Convert the list of arrays to a NumPy array for easier manipulation
    # yearly_data = np.array(yearly_data)

    return yearly_message, yearly_data

# %% [markdown]
# 红箭头指向的变量在2014的FNL中没找到
# ![](https://picgo-evan.oss-cn-guangzhou.aliyuncs.com/img/202310072037924.png)

# %%
years = np.arange(2014,2016+1)
month = 6
day   = 16
hour  = 0

variables = ['Temperature','U component of wind','V component of wind',
             'Geopotential height','Relative humidity','Surface pressure',
             'Mean sea level pressure','Volumetric soil moisture content',
             'Sea ice area fraction','Land-sea mask',
             'Water equivalent of accumulated snow depth (deprecated)',
             'Pressure','Tropopause pressure',]

# %%
messages, data = read_grib2_files(years,month,day,hour,variables,batchdir)

# %%
messages[2016]
# Out:
# [1:U component of wind:m s**-1 (instant):regular_ll:planetaryBoundaryLayer:level 0:fcst time 0 hrs:from 201606160000,
#  2:V component of wind:m s**-1 (instant):regular_ll:planetaryBoundaryLayer:level 0:fcst time 0 hrs:from 201606160000,
#  5:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 100 Pa:fcst time 0 hrs:from 201606160000,
#  6:Temperature:K (instant):regular_ll:isobaricInhPa:level 100 Pa:fcst time 0 hrs:from 201606160000,
#  7:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 100 Pa:fcst time 0 hrs:from 201606160000,
#  8:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 100 Pa:fcst time 0 hrs:from 201606160000,
#  9:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 100 Pa:fcst time 0 hrs:from 201606160000,
#  11:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 200 Pa:fcst time 0 hrs:from 201606160000,
#  12:Temperature:K (instant):regular_ll:isobaricInhPa:level 200 Pa:fcst time 0 hrs:from 201606160000,
#  13:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 200 Pa:fcst time 0 hrs:from 201606160000,
#  14:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 200 Pa:fcst time 0 hrs:from 201606160000,
#  15:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 200 Pa:fcst time 0 hrs:from 201606160000,
#  17:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 300 Pa:fcst time 0 hrs:from 201606160000,
#  18:Temperature:K (instant):regular_ll:isobaricInhPa:level 300 Pa:fcst time 0 hrs:from 201606160000,
#  19:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 300 Pa:fcst time 0 hrs:from 201606160000,
#  20:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 300 Pa:fcst time 0 hrs:from 201606160000,
#  21:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 300 Pa:fcst time 0 hrs:from 201606160000,
#  23:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 500 Pa:fcst time 0 hrs:from 201606160000,
#  24:Temperature:K (instant):regular_ll:isobaricInhPa:level 500 Pa:fcst time 0 hrs:from 201606160000,
#  25:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 500 Pa:fcst time 0 hrs:from 201606160000,
#  26:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 500 Pa:fcst time 0 hrs:from 201606160000,
#  27:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 500 Pa:fcst time 0 hrs:from 201606160000,
#  29:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 700 Pa:fcst time 0 hrs:from 201606160000,
#  30:Temperature:K (instant):regular_ll:isobaricInhPa:level 700 Pa:fcst time 0 hrs:from 201606160000,
#  31:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 700 Pa:fcst time 0 hrs:from 201606160000,
#  32:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 700 Pa:fcst time 0 hrs:from 201606160000,
#  33:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 700 Pa:fcst time 0 hrs:from 201606160000,
#  35:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201606160000,
#  36:Temperature:K (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201606160000,
#  37:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201606160000,
#  38:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201606160000,
#  39:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201606160000,
#  42:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201606160000,
#  43:Temperature:K (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201606160000,
#  44:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201606160000,
#  45:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201606160000,
#  46:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201606160000,
#  49:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201606160000,
#  50:Temperature:K (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201606160000,
#  51:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201606160000,
#  52:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201606160000,
#  53:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201606160000,
#  56:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201606160000,
#  57:Temperature:K (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201606160000,
#  58:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201606160000,
#  59:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201606160000,
#  60:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201606160000,
#  63:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201606160000,
#  64:Temperature:K (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201606160000,
#  65:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201606160000,
#  66:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201606160000,
#  67:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201606160000,
#  70:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201606160000,
#  71:Temperature:K (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201606160000,
#  72:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201606160000,
#  74:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201606160000,
#  75:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201606160000,
#  79:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201606160000,
#  80:Temperature:K (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201606160000,
#  81:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201606160000,
#  83:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201606160000,
#  84:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201606160000,
#  88:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201606160000,
#  89:Temperature:K (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201606160000,
#  90:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201606160000,
#  92:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201606160000,
#  93:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201606160000,
#  97:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201606160000,
#  98:Temperature:K (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201606160000,
#  99:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201606160000,
#  101:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201606160000,
#  102:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201606160000,
#  106:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201606160000,
#  107:Temperature:K (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201606160000,
#  108:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201606160000,
#  110:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201606160000,
#  111:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201606160000,
#  115:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201606160000,
#  116:Temperature:K (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201606160000,
#  117:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201606160000,
#  119:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201606160000,
#  120:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201606160000,
#  124:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201606160000,
#  125:Temperature:K (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201606160000,
#  126:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201606160000,
#  128:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201606160000,
#  129:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201606160000,
#  133:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201606160000,
#  134:Temperature:K (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201606160000,
#  135:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201606160000,
#  137:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201606160000,
#  138:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201606160000,
#  141:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201606160000,
#  142:Temperature:K (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201606160000,
#  143:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201606160000,
#  145:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201606160000,
#  146:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201606160000,
#  149:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201606160000,
#  150:Temperature:K (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201606160000,
#  151:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201606160000,
#  153:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201606160000,
#  154:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201606160000,
#  157:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201606160000,
#  158:Temperature:K (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201606160000,
#  159:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201606160000,
#  161:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201606160000,
#  162:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201606160000,
#  165:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201606160000,
#  166:Temperature:K (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201606160000,
#  167:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201606160000,
#  169:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201606160000,
#  170:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201606160000,
#  173:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201606160000,
#  174:Temperature:K (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201606160000,
#  175:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201606160000,
#  177:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201606160000,
#  178:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201606160000,
#  181:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201606160000,
#  182:Temperature:K (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201606160000,
#  183:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201606160000,
#  185:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201606160000,
#  186:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201606160000,
#  189:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201606160000,
#  190:Temperature:K (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201606160000,
#  191:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201606160000,
#  193:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201606160000,
#  194:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201606160000,
#  197:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201606160000,
#  198:Temperature:K (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201606160000,
#  199:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201606160000,
#  201:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201606160000,
#  202:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201606160000,
#  205:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201606160000,
#  206:Temperature:K (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201606160000,
#  207:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201606160000,
#  209:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201606160000,
#  210:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201606160000,
#  213:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201606160000,
#  214:Temperature:K (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201606160000,
#  215:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201606160000,
#  217:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201606160000,
#  218:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201606160000,
#  221:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201606160000,
#  222:Temperature:K (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201606160000,
#  223:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201606160000,
#  225:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201606160000,
#  226:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201606160000,
#  230:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201606160000,
#  231:Temperature:K (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201606160000,
#  232:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201606160000,
#  234:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201606160000,
#  235:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201606160000,
#  238:Temperature:K (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201606160000,
#  239:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201606160000,
#  241:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201606160000,
#  242:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201606160000,
#  246:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201606160000,
#  247:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201606160000,
#  249:Temperature:K (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201606160000,
#  251:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 0 hrs:from 201606160000,
#  253:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 0 hrs:from 201606160000,
#  255:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 0 hrs:from 201606160000,
#  257:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 1.0-2.0 m:fcst time 0 hrs:from 201606160000,
#  258:Water equivalent of accumulated snow depth (deprecated):kg m**-2 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201606160000,
#  276:Relative humidity:% (instant):regular_ll:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 0 hrs:from 201606160000,
#  281:Tropopause pressure:Pa (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201606160000,
#  283:Geopotential height:gpm (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201606160000,
#  284:Temperature:K (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201606160000,
#  285:U component of wind:m s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201606160000,
#  286:V component of wind:m s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201606160000,
#  288:Pressure:Pa (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201606160000,
#  290:Geopotential height:gpm (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201606160000,
#  291:U component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201606160000,
#  292:V component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201606160000,
#  293:Temperature:K (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201606160000,
#  294:Temperature:K (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201606160000,
#  296:Pressure:Pa (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201606160000,
#  297:U component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201606160000,
#  298:V component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201606160000,
#  299:Temperature:K (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201606160000,
#  302:Temperature:K (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201606160000,
#  303:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201606160000,
#  304:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201606160000,
#  305:Temperature:K (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201606160000,
#  306:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201606160000,
#  307:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201606160000,
#  308:Temperature:K (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201606160000,
#  309:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201606160000,
#  310:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201606160000,
#  311:Geopotential height:gpm (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201606160000,
#  312:Relative humidity:% (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201606160000,
#  313:Geopotential height:gpm (instant):regular_ll:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 201606160000,
#  314:Relative humidity:% (instant):regular_ll:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 201606160000,
#  315:Temperature:K (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201606160000,
#  316:Relative humidity:% (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201606160000,
#  318:U component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201606160000,
#  319:V component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201606160000,
#  324:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.33-1.0 sigma value:fcst time 0 hrs:from 201606160000,
#  325:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-1.0 sigma value:fcst time 0 hrs:from 201606160000,
#  326:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.72-0.94 sigma value:fcst time 0 hrs:from 201606160000,
#  327:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-0.72 sigma value:fcst time 0 hrs:from 201606160000,
#  328:Temperature:K (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201606160000,
#  330:Relative humidity:% (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201606160000,
#  331:U component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201606160000,
#  332:V component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201606160000,
#  337:Land-sea mask:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201606160000,
#  338:Sea ice area fraction:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201606160000,
#  339:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  340:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  341:Temperature:K (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  342:Geopotential height:gpm (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  343:Pressure:Pa (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  345:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  346:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  347:Temperature:K (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  348:Geopotential height:gpm (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000,
#  349:Pressure:Pa (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201606160000]

# %%
data[2016][0].shape
# Out:
# (181, 360)

# %% [markdown]
# 依据2014年元信息对后续年份做筛选

# %%
info = []
for msg in messages[2014]:
    if msg['name'] not in info:
        info.append(msg['name'])
info
# Out:
# ['Mean sea level pressure',
#  'Geopotential height',
#  'Temperature',
#  'U component of wind',
#  'V component of wind',
#  'Relative humidity',
#  'Surface pressure',
#  'Volumetric soil moisture content',
#  'Water equivalent of accumulated snow depth (deprecated)',
#  'Tropopause pressure',
#  'Pressure',
#  'Land-sea mask',
#  'Sea ice area fraction']

# %%
messages[2015] = [msg for msg in messages[2015] if msg['name'] in info]

# %%
messages[2014][0].keys()
# Out:
# ['globalDomain',
#  'GRIBEditionNumber',
#  'tablesVersionLatestOfficial',
#  'tablesVersionLatest',
#  'grib2divider',
#  'angleSubdivisions',
#  'missingValue',
#  'ieeeFloats',
#  'isHindcast',
#  'section0Length',
#  'identifier',
#  'discipline',
#  'editionNumber',
#  'totalLength',
#  'sectionNumber',
#  'section1Length',
#  'numberOfSection',
#  'centre',
#  'centreDescription',
#  'subCentre',
#  'tablesVersion',
#  'masterDir',
#  'localTablesVersion',
#  'significanceOfReferenceTime',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'second',
#  'dataDate',
#  'julianDay',
#  'dataTime',
#  'productionStatusOfProcessedData',
#  'typeOfProcessedData',
#  'md5Section1',
#  'selectStepTemplateInterval',
#  'selectStepTemplateInstant',
#  'stepType',
#  'is_chemical',
#  'is_chemical_distfn',
#  'is_chemical_srcsink',
#  'is_aerosol',
#  'is_aerosol_optical',
#  'setCalendarId',
#  'deleteCalendarId',
#  'sectionNumber',
#  'grib2LocalSectionPresent',
#  'deleteLocalDefinition',
#  'sectionNumber',
#  'gridDescriptionSectionPresent',
#  'section3Length',
#  'numberOfSection',
#  'sourceOfGridDefinition',
#  'numberOfDataPoints',
#  'numberOfOctectsForNumberOfPoints',
#  'interpretationOfNumberOfPoints',
#  'PLPresent',
#  'gridDefinitionTemplateNumber',
#  'gridDefinitionDescription',
#  'shapeOfTheEarth',
#  'scaleFactorOfRadiusOfSphericalEarth',
#  'scaledValueOfRadiusOfSphericalEarth',
#  'scaleFactorOfEarthMajorAxis',
#  'scaledValueOfEarthMajorAxis',
#  'scaleFactorOfEarthMinorAxis',
#  'scaledValueOfEarthMinorAxis',
#  'radius',
#  'isGridded',
#  'Ni',
#  'Nj',
#  'basicAngleOfTheInitialProductionDomain',
#  'mBasicAngle',
#  'angleMultiplier',
#  'mAngleMultiplier',
#  'subdivisionsOfBasicAngle',
#  'angleDivisor',
#  'latitudeOfFirstGridPoint',
#  'longitudeOfFirstGridPoint',
#  'resolutionAndComponentFlags',
#  'resolutionAndComponentFlags1',
#  'resolutionAndComponentFlags2',
#  'iDirectionIncrementGiven',
#  'jDirectionIncrementGiven',
#  'uvRelativeToGrid',
#  'resolutionAndComponentFlags6',
#  'resolutionAndComponentFlags7',
#  'resolutionAndComponentFlags8',
#  'ijDirectionIncrementGiven',
#  'latitudeOfLastGridPoint',
#  'longitudeOfLastGridPoint',
#  'iDirectionIncrement',
#  'jDirectionIncrement',
#  'scanningMode',
#  'iScansNegatively',
#  'jScansPositively',
#  'jPointsAreConsecutive',
#  'alternativeRowScanning',
#  'iScansPositively',
#  'jScansNegatively',
#  'scanningMode5',
#  'scanningMode6',
#  'scanningMode7',
#  'scanningMode8',
#  'g2grid',
#  'latitudeOfFirstGridPointInDegrees',
#  'longitudeOfFirstGridPointInDegrees',
#  'latitudeOfLastGridPointInDegrees',
#  'longitudeOfLastGridPointInDegrees',
#  'iDirectionIncrementInDegrees',
#  'jDirectionIncrementInDegrees',
#  'latLonValues',
#  'latitudes',
#  'longitudes',
#  'distinctLatitudes',
#  'distinctLongitudes',
#  'gridType',
#  'md5Section3',
#  'isSpectral',
#  'sectionNumber',
#  'section4Length',
#  'numberOfSection',
#  'NV',
#  'neitherPresent',
#  'datasetForLocal',
#  'productDefinitionTemplateNumber',
#  'genVertHeightCoords',
#  'parameterCategory',
#  'parameterNumber',
#  'parameterUnits',
#  'parameterName',
#  'typeOfGeneratingProcess',
#  'backgroundProcess',
#  'generatingProcessIdentifier',
#  'hoursAfterDataCutoff',
#  'minutesAfterDataCutoff',
#  'indicatorOfUnitOfTimeRange',
#  'stepUnits',
#  'forecastTime',
#  'startStep',
#  'endStep',
#  'stepRange',
#  'stepTypeInternal',
#  'validityDate',
#  'validityTime',
#  'validityDateTime',
#  'typeOfFirstFixedSurface',
#  'unitsOfFirstFixedSurface',
#  'nameOfFirstFixedSurface',
#  'scaleFactorOfFirstFixedSurface',
#  'scaledValueOfFirstFixedSurface',
#  'typeOfSecondFixedSurface',
#  'unitsOfSecondFixedSurface',
#  'nameOfSecondFixedSurface',
#  'scaleFactorOfSecondFixedSurface',
#  'scaledValueOfSecondFixedSurface',
#  'pressureUnits',
#  'typeOfLevel',
#  'level',
#  'bottomLevel',
#  'topLevel',
#  'tempPressureUnits',
#  'levtype',
#  'paramIdECMF',
#  'paramId',
#  'shortNameECMF',
#  'shortName',
#  'unitsECMF',
#  'units',
#  'nameECMF',
#  'name',
#  'cfNameECMF',
#  'cfName',
#  'cfVarNameECMF',
#  'cfVarName',
#  'modelName',
#  'ifsParam',
#  'PVPresent',
#  'deletePV',
#  'md5Section4',
#  'lengthOfHeaders',
#  'md5Headers',
#  'sectionNumber',
#  'section5Length',
#  'numberOfSection',
#  'numberOfValues',
#  'dataRepresentationTemplateNumber',
#  'packingType',
#  'referenceValue',
#  'referenceValueError',
#  'binaryScaleFactor',
#  'decimalScaleFactor',
#  'optimizeScaleFactor',
#  'bitsPerValue',
#  'typeOfOriginalFieldValues',
#  'typeOfCompressionUsed',
#  'targetCompressionRatio',
#  'md5Section5',
#  'sectionNumber',
#  'section6Length',
#  'numberOfSection',
#  'bitMapIndicator',
#  'bitmapPresent',
#  'md5Section6',
#  'sectionNumber',
#  'section7Length',
#  'numberOfSection',
#  'codedValues',
#  'values',
#  'maximum',
#  'minimum',
#  'average',
#  'standardDeviation',
#  'skewness',
#  'kurtosis',
#  'isConstant',
#  'numberOfMissing',
#  'changeDecimalPrecision',
#  'decimalPrecision',
#  'setBitsPerValue',
#  'setPackingType',
#  'getNumberOfValues',
#  'scaleValuesBy',
#  'offsetValuesBy',
#  'productType',
#  'md5Section7',
#  'section8Length',
#  'analDate',
#  'validDate']

# %%
messages[2014][0]['name']
# Out:
# 'Mean sea level pressure'

# %%
messages[2015]
# Out:
# [1:U component of wind:m s**-1 (instant):regular_ll:planetaryBoundaryLayer:level 0:fcst time 0 hrs:from 201506160000,
#  2:V component of wind:m s**-1 (instant):regular_ll:planetaryBoundaryLayer:level 0:fcst time 0 hrs:from 201506160000,
#  5:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201506160000,
#  6:Temperature:K (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201506160000,
#  7:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201506160000,
#  8:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201506160000,
#  9:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 1000 Pa:fcst time 0 hrs:from 201506160000,
#  12:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201506160000,
#  13:Temperature:K (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201506160000,
#  14:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201506160000,
#  15:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201506160000,
#  16:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 2000 Pa:fcst time 0 hrs:from 201506160000,
#  19:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201506160000,
#  20:Temperature:K (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201506160000,
#  21:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201506160000,
#  22:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201506160000,
#  23:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 3000 Pa:fcst time 0 hrs:from 201506160000,
#  26:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201506160000,
#  27:Temperature:K (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201506160000,
#  28:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201506160000,
#  29:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201506160000,
#  30:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 5000 Pa:fcst time 0 hrs:from 201506160000,
#  33:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201506160000,
#  34:Temperature:K (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201506160000,
#  35:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201506160000,
#  36:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201506160000,
#  37:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 7000 Pa:fcst time 0 hrs:from 201506160000,
#  40:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201506160000,
#  41:Temperature:K (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201506160000,
#  42:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201506160000,
#  44:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201506160000,
#  45:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 10000 Pa:fcst time 0 hrs:from 201506160000,
#  49:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201506160000,
#  50:Temperature:K (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201506160000,
#  51:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201506160000,
#  53:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201506160000,
#  54:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 15000 Pa:fcst time 0 hrs:from 201506160000,
#  58:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201506160000,
#  59:Temperature:K (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201506160000,
#  60:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201506160000,
#  62:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201506160000,
#  63:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 20000 Pa:fcst time 0 hrs:from 201506160000,
#  67:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201506160000,
#  68:Temperature:K (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201506160000,
#  69:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201506160000,
#  71:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201506160000,
#  72:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 25000 Pa:fcst time 0 hrs:from 201506160000,
#  76:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201506160000,
#  77:Temperature:K (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201506160000,
#  78:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201506160000,
#  80:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201506160000,
#  81:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 30000 Pa:fcst time 0 hrs:from 201506160000,
#  85:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201506160000,
#  86:Temperature:K (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201506160000,
#  87:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201506160000,
#  89:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201506160000,
#  90:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 35000 Pa:fcst time 0 hrs:from 201506160000,
#  94:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201506160000,
#  95:Temperature:K (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201506160000,
#  96:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201506160000,
#  98:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201506160000,
#  99:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 40000 Pa:fcst time 0 hrs:from 201506160000,
#  103:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201506160000,
#  104:Temperature:K (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201506160000,
#  105:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201506160000,
#  107:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201506160000,
#  108:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 45000 Pa:fcst time 0 hrs:from 201506160000,
#  111:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201506160000,
#  112:Temperature:K (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201506160000,
#  113:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201506160000,
#  115:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201506160000,
#  116:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 50000 Pa:fcst time 0 hrs:from 201506160000,
#  119:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201506160000,
#  120:Temperature:K (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201506160000,
#  121:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201506160000,
#  123:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201506160000,
#  124:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 55000 Pa:fcst time 0 hrs:from 201506160000,
#  127:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201506160000,
#  128:Temperature:K (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201506160000,
#  129:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201506160000,
#  131:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201506160000,
#  132:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 60000 Pa:fcst time 0 hrs:from 201506160000,
#  135:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201506160000,
#  136:Temperature:K (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201506160000,
#  137:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201506160000,
#  139:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201506160000,
#  140:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 65000 Pa:fcst time 0 hrs:from 201506160000,
#  143:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201506160000,
#  144:Temperature:K (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201506160000,
#  145:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201506160000,
#  147:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201506160000,
#  148:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 70000 Pa:fcst time 0 hrs:from 201506160000,
#  151:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201506160000,
#  152:Temperature:K (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201506160000,
#  153:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201506160000,
#  155:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201506160000,
#  156:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 75000 Pa:fcst time 0 hrs:from 201506160000,
#  159:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201506160000,
#  160:Temperature:K (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201506160000,
#  161:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201506160000,
#  163:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201506160000,
#  164:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 80000 Pa:fcst time 0 hrs:from 201506160000,
#  167:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201506160000,
#  168:Temperature:K (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201506160000,
#  169:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201506160000,
#  171:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201506160000,
#  172:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 85000 Pa:fcst time 0 hrs:from 201506160000,
#  175:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201506160000,
#  176:Temperature:K (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201506160000,
#  177:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201506160000,
#  179:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201506160000,
#  180:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 90000 Pa:fcst time 0 hrs:from 201506160000,
#  183:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201506160000,
#  184:Temperature:K (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201506160000,
#  185:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201506160000,
#  187:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201506160000,
#  188:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 92500 Pa:fcst time 0 hrs:from 201506160000,
#  191:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201506160000,
#  192:Temperature:K (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201506160000,
#  193:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201506160000,
#  195:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201506160000,
#  196:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 95000 Pa:fcst time 0 hrs:from 201506160000,
#  200:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201506160000,
#  201:Temperature:K (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201506160000,
#  202:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201506160000,
#  204:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201506160000,
#  205:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 97500 Pa:fcst time 0 hrs:from 201506160000,
#  208:Temperature:K (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201506160000,
#  209:Relative humidity:% (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201506160000,
#  211:U component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201506160000,
#  212:V component of wind:m s**-1 (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201506160000,
#  216:Geopotential height:gpm (instant):regular_ll:isobaricInhPa:level 100000 Pa:fcst time 0 hrs:from 201506160000,
#  217:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201506160000,
#  219:Temperature:K (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201506160000,
#  221:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.0-0.1 m:fcst time 0 hrs:from 201506160000,
#  223:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.1-0.4 m:fcst time 0 hrs:from 201506160000,
#  225:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 0.4-1.0 m:fcst time 0 hrs:from 201506160000,
#  227:Volumetric soil moisture content:Proportion (instant):regular_ll:depthBelowLandLayer:levels 1.0-2.0 m:fcst time 0 hrs:from 201506160000,
#  228:Water equivalent of accumulated snow depth (deprecated):kg m**-2 (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201506160000,
#  246:Relative humidity:% (instant):regular_ll:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 0 hrs:from 201506160000,
#  251:Tropopause pressure:Pa (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201506160000,
#  253:Geopotential height:gpm (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201506160000,
#  254:Temperature:K (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201506160000,
#  255:U component of wind:m s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201506160000,
#  256:V component of wind:m s**-1 (instant):regular_ll:tropopause:level 0:fcst time 0 hrs:from 201506160000,
#  258:Pressure:Pa (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201506160000,
#  260:Geopotential height:gpm (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201506160000,
#  261:U component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201506160000,
#  262:V component of wind:m s**-1 (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201506160000,
#  263:Temperature:K (instant):regular_ll:maxWind:level 0:fcst time 0 hrs:from 201506160000,
#  264:Temperature:K (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201506160000,
#  266:Pressure:Pa (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201506160000,
#  267:U component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201506160000,
#  268:V component of wind:m s**-1 (instant):regular_ll:heightAboveGround:level 80 m:fcst time 0 hrs:from 201506160000,
#  269:Temperature:K (instant):regular_ll:heightAboveGround:level 100 m:fcst time 0 hrs:from 201506160000,
#  272:Temperature:K (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201506160000,
#  273:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201506160000,
#  274:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 1829 m:fcst time 0 hrs:from 201506160000,
#  275:Temperature:K (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201506160000,
#  276:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201506160000,
#  277:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 2743 m:fcst time 0 hrs:from 201506160000,
#  278:Temperature:K (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201506160000,
#  279:U component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201506160000,
#  280:V component of wind:m s**-1 (instant):regular_ll:heightAboveSea:level 3658 m:fcst time 0 hrs:from 201506160000,
#  281:Geopotential height:gpm (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201506160000,
#  282:Relative humidity:% (instant):regular_ll:isothermZero:level 0:fcst time 0 hrs:from 201506160000,
#  283:Geopotential height:gpm (instant):regular_ll:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 201506160000,
#  284:Relative humidity:% (instant):regular_ll:highestTroposphericFreezing:level 0:fcst time 0 hrs:from 201506160000,
#  285:Temperature:K (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201506160000,
#  286:Relative humidity:% (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201506160000,
#  288:U component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201506160000,
#  289:V component of wind:m s**-1 (instant):regular_ll:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 0 hrs:from 201506160000,
#  294:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.33-1.0 sigma value:fcst time 0 hrs:from 201506160000,
#  295:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-1.0 sigma value:fcst time 0 hrs:from 201506160000,
#  296:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.72-0.94 sigma value:fcst time 0 hrs:from 201506160000,
#  297:Relative humidity:% (instant):regular_ll:sigmaLayer:levels 0.44-0.72 sigma value:fcst time 0 hrs:from 201506160000,
#  298:Temperature:K (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201506160000,
#  300:Relative humidity:% (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201506160000,
#  301:U component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201506160000,
#  302:V component of wind:m s**-1 (instant):regular_ll:sigma:level 0.995 sigma value:fcst time 0 hrs:from 201506160000,
#  307:Land-sea mask:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201506160000,
#  308:Sea ice area fraction:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201506160000,
#  309:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  310:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  311:Temperature:K (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  312:Geopotential height:gpm (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  313:Pressure:Pa (instant):regular_ll:potentialVorticity:level 2e-06 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  315:U component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  316:V component of wind:m s**-1 (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  317:Temperature:K (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  318:Geopotential height:gpm (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000,
#  319:Pressure:Pa (instant):regular_ll:potentialVorticity:level -2.147481648 K m2 kg-1 s-1:fcst time 0 hrs:from 201506160000]
