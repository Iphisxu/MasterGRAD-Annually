# %%
import pygrib as pg
import numpy as np
# import xarray as xr
# import cfgrib
import os
import shutil

# %% [markdown]
# # 测试

# %%
def fetch_testfile(year, month, day, hour, target_path):
    
    if month == 7:
        monthname = 'Jul'
    elif month == 9:
        monthname = 'Sep'
    elif month == 10:
        monthname = 'Oct'
        
    filename = f"fnl_{year}{month:02d}{day:02d}_{hour:02d}_00.grib2"
    source_path= f"F:/Data/Graduation/fnl_months/{monthname}/{year}{month:02d}/{filename}"
    
    if not os.path.exists(target_path):
        os.makedirs(target_path)
    
    if os.path.exists(source_path):
        shutil.copy(source_path, target_path)
        print(f"{filename} copied to target_path")
        
        return filename
    else:
        raise FileNotFoundError(f"{source_path} not found")


file_list = []
years = range(2014,2023)
month = 9

day = 1
hour = 0

target_path='F:/Data/Graduation/fnl_months/test/'
print(target_path)

for year in years:
    try:
        file_name = fetch_testfile(year,month,day,hour,target_path)
        file_list.append(target_path+file_name)
    except FileNotFoundError as e:
        print(e)

# %%
def get_fnl(year,month,day,hour):
    
    if month == 7:
        monthname = 'Jul'
    elif month == 9:
        monthname = 'Sep'
    elif month == 10:
        monthname = 'Oct'
        
    filename = f"fnl_{year}{month:02d}{day:02d}_{hour:02d}_00.grib2"
    # path = f"F:/Data/Graduation/fnl_months/{monthname}/{year}{month:02d}/{filename}"
    path = f"F:/Data/Graduation/fnl_months/test/{filename}"
    
    if os.path.exists(path):
        return path
    else:
        raise FileNotFoundError(f"{path} not found")
    
file_list = []
years = range(2014,2023)
month = 9
day = 1
hour = 0

for year in years:
    try:
        file_path = get_fnl(year,month,day,hour)
        file_list.append(file_path)
    except FileNotFoundError as e:
        print(e)
file_list
# Out:
# ['F:/Data/Graduation/fnl_months/test/fnl_20140901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20150901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20160901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20170901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20180901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20190901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20200901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20210901_00_00.grib2',
#  'F:/Data/Graduation/fnl_months/test/fnl_20220901_00_00.grib2']

# %% [markdown]
# ## 读取单个文件的变量

# %%
grb_in = pg.open(file_list[-1])
num_message = grb_in.messages
print('There are',num_message,'messages in this grib2 file')
# Out:
# There are 696 messages in this grib2 file

# %%
for message in grb_in:
    data = message.data()[0]
    meta = message.keys()
    if len(data.shape) != 2:
        print(message)

# %%
for file in file_list:
    grb = pg.open(file)
    with open(f'param_{file[-20:-16]}.csv','w') as f:
        for message in grb:
            output = f"{message['parameterNumber']}, {message['name']}, {message['units']}, {message['level']}, {message['paramId']}\n"
            f.write(output)
        f.close()

# %%
msg = grb_in.message(1)
print(msg['parameterNumber'],msg['parameterName'],msg['units'],msg['level'],msg['paramId'])
# Out:
# 1 Pressure reduced to MSL Pa 0 260074

# %%
data[0]
# Out:
# array([[ -24.87,  -24.87,  -24.87, ...,  -24.87,  -24.87,  -24.87],
#        [ -28.41,  -28.51,  -28.61, ...,  -28.23,  -28.29,  -28.35],
#        [ -31.41,  -31.59,  -31.81, ...,  -31.01,  -31.15,  -31.27],
#        ...,
#        [-174.61, -175.03, -175.47, ..., -174.15, -174.39, -174.49],
#        [-181.75, -181.97, -182.21, ..., -181.49, -181.61, -181.67],
#        [-187.85, -187.85, -187.85, ..., -187.85, -187.85, -187.85]])

# %%
data[1]
# Out:
# array([[ 90.,  90.,  90., ...,  90.,  90.,  90.],
#        [ 89.,  89.,  89., ...,  89.,  89.,  89.],
#        [ 88.,  88.,  88., ...,  88.,  88.,  88.],
#        ...,
#        [-88., -88., -88., ..., -88., -88., -88.],
#        [-89., -89., -89., ..., -89., -89., -89.],
#        [-90., -90., -90., ..., -90., -90., -90.]])

# %%
data[2]
# Out:
# array([[  0.,   1.,   2., ..., 357., 358., 359.],
#        [  0.,   1.,   2., ..., 357., 358., 359.],
#        [  0.,   1.,   2., ..., 357., 358., 359.],
#        ...,
#        [  0.,   1.,   2., ..., 357., 358., 359.],
#        [  0.,   1.,   2., ..., 357., 358., 359.],
#        [  0.,   1.,   2., ..., 357., 358., 359.]])

# %% [markdown]
# ## 读取多个文件的变量

# %%
for file in file_list:
    grb = pg.open(file)
    print(file[-20:-9],'  ',grb.messages)
    grb.close()
# Out:
# 20140901_00    288
# 20150901_00    322
# 20160901_00    352
# 20170901_00    353
# 20180901_00    353
# 20190901_00    520
# 20200901_00    522
# 20210901_00    696
# 20220901_00    696

# %%
grb_2014 = pg.open(file_list[0])
grb_2022 = pg.open(file_list[-1])

# %%
ids_2014 = [message['parameterName'] + '_' + str(message['level']) for message in grb_2014]
ids_2022 = [message['parameterName'] + '_' + str(message['level']) for message in grb_2022]

# %%
ids_2014
# Out:
# ['Geopotential height_10',
#  'Temperature_10',
#  'u-component of wind_10',
#  'v-component of wind_10',
#  'Absolute vorticity_10',
#  '192_10',
#  'Geopotential height_20',
#  'Temperature_20',
#  'u-component of wind_20',
#  'v-component of wind_20',
#  'Absolute vorticity_20',
#  '192_20',
#  'Geopotential height_30',
#  'Temperature_30',
#  'u-component of wind_30',
#  'v-component of wind_30',
#  'Absolute vorticity_30',
#  '192_30',
#  'Geopotential height_50',
#  'Temperature_50',
#  'u-component of wind_50',
#  'v-component of wind_50',
#  'Absolute vorticity_50',
#  '192_50',
#  'Geopotential height_70',
#  'Temperature_70',
#  'u-component of wind_70',
#  'v-component of wind_70',
#  'Absolute vorticity_70',
#  '192_70',
#  'Geopotential height_100',
#  'Temperature_100',
#  'Relative humidity_100',
#  'Vertical velocity (pressure)_100',
#  'u-component of wind_100',
#  'v-component of wind_100',
#  'Absolute vorticity_100',
#  'Cloud mixing ratio_100',
#  '192_100',
#  'Geopotential height_150',
#  'Temperature_150',
#  'Relative humidity_150',
#  'Vertical velocity (pressure)_150',
#  'u-component of wind_150',
#  'v-component of wind_150',
#  'Absolute vorticity_150',
#  'Cloud mixing ratio_150',
#  'Geopotential height_200',
#  'Temperature_200',
#  'Relative humidity_200',
#  'Vertical velocity (pressure)_200',
#  'u-component of wind_200',
#  'v-component of wind_200',
#  'Absolute vorticity_200',
#  'Cloud mixing ratio_200',
#  'Geopotential height_250',
#  'Temperature_250',
#  'Relative humidity_250',
#  'Vertical velocity (pressure)_250',
#  'u-component of wind_250',
#  'v-component of wind_250',
#  'Absolute vorticity_250',
#  'Cloud mixing ratio_250',
#  'Geopotential height_300',
#  'Temperature_300',
#  'Relative humidity_300',
#  'Vertical velocity (pressure)_300',
#  'u-component of wind_300',
#  'v-component of wind_300',
#  'Absolute vorticity_300',
#  'Cloud mixing ratio_300',
#  'Geopotential height_350',
#  'Temperature_350',
#  'Relative humidity_350',
#  'Vertical velocity (pressure)_350',
#  'u-component of wind_350',
#  'v-component of wind_350',
#  'Absolute vorticity_350',
#  'Cloud mixing ratio_350',
#  'Geopotential height_400',
#  'Temperature_400',
#  'Relative humidity_400',
#  'Vertical velocity (pressure)_400',
#  'u-component of wind_400',
#  'v-component of wind_400',
#  'Absolute vorticity_400',
#  'Cloud mixing ratio_400',
#  'Geopotential height_450',
#  'Temperature_450',
#  'Relative humidity_450',
#  'Vertical velocity (pressure)_450',
#  'u-component of wind_450',
#  'v-component of wind_450',
#  'Absolute vorticity_450',
#  'Cloud mixing ratio_450',
#  'Geopotential height_500',
#  'Temperature_500',
#  'Relative humidity_500',
#  'Vertical velocity (pressure)_500',
#  'u-component of wind_500',
#  'v-component of wind_500',
#  'Absolute vorticity_500',
#  'Cloud mixing ratio_500',
#  'Geopotential height_550',
#  'Temperature_550',
#  'Relative humidity_550',
#  'Vertical velocity (pressure)_550',
#  'u-component of wind_550',
#  'v-component of wind_550',
#  'Absolute vorticity_550',
#  'Cloud mixing ratio_550',
#  'Geopotential height_600',
#  'Temperature_600',
#  'Relative humidity_600',
#  'Vertical velocity (pressure)_600',
#  'u-component of wind_600',
#  'v-component of wind_600',
#  'Absolute vorticity_600',
#  'Cloud mixing ratio_600',
#  'Geopotential height_650',
#  'Temperature_650',
#  'Relative humidity_650',
#  'Vertical velocity (pressure)_650',
#  'u-component of wind_650',
#  'v-component of wind_650',
#  'Absolute vorticity_650',
#  'Cloud mixing ratio_650',
#  'Geopotential height_700',
#  'Temperature_700',
#  'Relative humidity_700',
#  'Vertical velocity (pressure)_700',
#  'u-component of wind_700',
#  'v-component of wind_700',
#  'Absolute vorticity_700',
#  'Cloud mixing ratio_700',
#  'Geopotential height_750',
#  'Temperature_750',
#  'Relative humidity_750',
#  'Vertical velocity (pressure)_750',
#  'u-component of wind_750',
#  'v-component of wind_750',
#  'Absolute vorticity_750',
#  'Cloud mixing ratio_750',
#  'Geopotential height_800',
#  'Temperature_800',
#  'Relative humidity_800',
#  'Vertical velocity (pressure)_800',
#  'u-component of wind_800',
#  'v-component of wind_800',
#  'Absolute vorticity_800',
#  'Cloud mixing ratio_800',
#  'Geopotential height_850',
#  'Temperature_850',
#  'Relative humidity_850',
#  'Vertical velocity (pressure)_850',
#  'u-component of wind_850',
#  'v-component of wind_850',
#  'Absolute vorticity_850',
#  'Cloud mixing ratio_850',
#  'Geopotential height_900',
#  'Temperature_900',
#  'Relative humidity_900',
#  'Vertical velocity (pressure)_900',
#  'u-component of wind_900',
#  'v-component of wind_900',
#  'Absolute vorticity_900',
#  'Cloud mixing ratio_900',
#  'Geopotential height_925',
#  'Temperature_925',
#  'Relative humidity_925',
#  'Vertical velocity (pressure)_925',
#  'u-component of wind_925',
#  'v-component of wind_925',
#  'Absolute vorticity_925',
#  'Cloud mixing ratio_925',
#  'Geopotential height_950',
#  'Temperature_950',
#  'Relative humidity_950',
#  'Vertical velocity (pressure)_950',
#  'u-component of wind_950',
#  'v-component of wind_950',
#  'Absolute vorticity_950',
#  'Cloud mixing ratio_950',
#  'Geopotential height_975',
#  'Temperature_975',
#  'Relative humidity_975',
#  'Vertical velocity (pressure)_975',
#  'u-component of wind_975',
#  'v-component of wind_975',
#  'Absolute vorticity_975',
#  'Cloud mixing ratio_975',
#  'Geopotential height_1000',
#  'Temperature_1000',
#  'Relative humidity_1000',
#  'Vertical velocity (pressure)_1000',
#  'u-component of wind_1000',
#  'v-component of wind_1000',
#  'Absolute vorticity_1000',
#  'Cloud mixing ratio_1000',
#  'Pressure_0',
#  'Geopotential height_0',
#  'Temperature_0',
#  'Temperature_0',
#  '192_0',
#  'Temperature_0',
#  '192_0',
#  'Temperature_0',
#  '192_0',
#  'Temperature_1',
#  '192_1',
#  'Water equivalent of accumulated snow depth_0',
#  '200_0',
#  'Temperature_2',
#  'Specific humidity_2',
#  'Relative humidity_2',
#  'u-component of wind_10',
#  'v-component of wind_10',
#  '192_0',
#  'Convective available potential energy_0',
#  'Convective inhibition_0',
#  'Precipitable water_0',
#  'Cloud water_0',
#  'Relative humidity_0',
#  'Total ozone_0',
#  'Total cloud cover_0',
#  'Pressure_0',
#  'Geopotential height_0',
#  'Temperature_0',
#  'u-component of wind_0',
#  'v-component of wind_0',
#  '192_0',
#  'Pressure_0',
#  'Geopotential height_0',
#  'u-component of wind_0',
#  'v-component of wind_0',
#  'Temperature_0',
#  'Temperature_457',
#  'u-component of wind_457',
#  'v-component of wind_457',
#  'Temperature_914',
#  'u-component of wind_914',
#  'v-component of wind_914',
#  'Temperature_1524',
#  'u-component of wind_1524',
#  'v-component of wind_1524',
#  'Geopotential height_0',
#  'Relative humidity_0',
#  'Geopotential height_0',
#  'Relative humidity_0',
#  'Temperature_3000',
#  'Relative humidity_3000',
#  'Specific humidity_3000',
#  'u-component of wind_3000',
#  'v-component of wind_3000',
#  '193_0',
#  'Convective available potential energy_18000',
#  'Convective inhibition_18000',
#  '196_0',
#  'Relative humidity_0',
#  'Relative humidity_0',
#  'Relative humidity_1',
#  'Relative humidity_0',
#  'Temperature_1',
#  'Potential temperature_1',
#  'Relative humidity_1',
#  'u-component of wind_1',
#  'v-component of wind_1',
#  'Vertical velocity (pressure)_1',
#  'Land cover (0=land, 1=sea)_0',
#  'Ice cover_0',
#  'u-component of wind_-2147481',
#  'v-component of wind_-2147481',
#  'Temperature_-2147481',
#  'Geopotential height_-2147481',
#  'Pressure_-2147481',
#  '192_-2147481',
#  'u-component of wind_2',
#  'v-component of wind_2',
#  'Temperature_2',
#  'Geopotential height_2',
#  'Pressure_2',
#  '192_2',
#  'Pressure reduced to MSL_0',
#  '193_500',
#  'Geopotential height anomaly_1000',
#  'Geopotential height anomaly_500',
#  '197_500']

# %%
for i, id_2022 in enumerate(ids_2022):
    try:
        j = ids_2014.index(id_2022)
        # 如果找到相同ID的消息，则输出其位置和ID
        print(f"Message {i} (ID: {id_2022}) in 2022 data corresponds to message {j} in 2014 data.")
    except ValueError:
        # 如果未找到相同ID的消息，则输出警告
        print(f"Warning: Message {i} (ID: {id_2022}) in 2022 data has no corresponding message in 2014 data.")
        continue
# Out:
# Message 0 (ID: Pressure reduced to MSL_0) in 2022 data corresponds to message 282 in 2014 data.
# Warning: Message 1 (ID: Cloud mixing ratio_1) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 2 (ID: Ice water mixing ratio_1) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 3 (ID: Rain mixing ratio_1) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 4 (ID: Snow mixing ratio_1) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 5 (ID: Graupel (snow pellets)_1) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 6 (ID: 195_1) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 7 (ID: 195_2) in 2022 data has no corresponding message in 2014 data.
# Message 8 (ID: 196_0) in 2022 data corresponds to message 257 in 2014 data.
# Warning: Message 9 (ID: Visibility_0) in 2022 data has no corresponding message in 2014 data.
# Message 10 (ID: u-component of wind_0) in 2022 data corresponds to message 228 in 2014 data.
# Message 11 (ID: v-component of wind_0) in 2022 data corresponds to message 229 in 2014 data.
# Warning: Message 12 (ID: 224_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 13 (ID: Wind speed (gust)_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 14 (ID: Geopotential height_1) in 2022 data has no corresponding message in 2014 data.
# Message 15 (ID: Temperature_1) in 2022 data corresponds to message 208 in 2014 data.
# Message 16 (ID: Relative humidity_1) in 2022 data corresponds to message 260 in 2014 data.
# Warning: Message 17 (ID: Specific humidity_1) in 2022 data has no corresponding message in 2014 data.
# Message 18 (ID: Vertical velocity (pressure)_1) in 2022 data corresponds to message 267 in 2014 data.
# Warning: Message 19 (ID: Vertical velocity (geometric)_1) in 2022 data has no corresponding message in 2014 data.
# Message 20 (ID: u-component of wind_1) in 2022 data corresponds to message 265 in 2014 data.
# Message 21 (ID: v-component of wind_1) in 2022 data corresponds to message 266 in 2014 data.
# Warning: Message 22 (ID: Absolute vorticity_1) in 2022 data has no corresponding message in 2014 data.
# Message 23 (ID: 192_1) in 2022 data corresponds to message 209 in 2014 data.
# Message 24 (ID: Geopotential height_2) in 2022 data corresponds to message 279 in 2014 data.
# Message 25 (ID: Temperature_2) in 2022 data corresponds to message 212 in 2014 data.
# Message 26 (ID: Relative humidity_2) in 2022 data corresponds to message 214 in 2014 data.
# Message 27 (ID: Specific humidity_2) in 2022 data corresponds to message 213 in 2014 data.
# Warning: Message 28 (ID: Vertical velocity (pressure)_2) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 29 (ID: Vertical velocity (geometric)_2) in 2022 data has no corresponding message in 2014 data.
# Message 30 (ID: u-component of wind_2) in 2022 data corresponds to message 276 in 2014 data.
# Message 31 (ID: v-component of wind_2) in 2022 data corresponds to message 277 in 2014 data.
# Warning: Message 32 (ID: Absolute vorticity_2) in 2022 data has no corresponding message in 2014 data.
# Message 33 (ID: 192_2) in 2022 data corresponds to message 281 in 2014 data.
# Warning: Message 34 (ID: Geopotential height_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 35 (ID: Temperature_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 36 (ID: Relative humidity_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 37 (ID: Specific humidity_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 38 (ID: Vertical velocity (pressure)_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 39 (ID: Vertical velocity (geometric)_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 40 (ID: u-component of wind_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 41 (ID: v-component of wind_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 42 (ID: Absolute vorticity_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 43 (ID: 192_4) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 44 (ID: Geopotential height_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 45 (ID: Temperature_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 46 (ID: Relative humidity_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 47 (ID: Specific humidity_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 48 (ID: Vertical velocity (pressure)_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 49 (ID: Vertical velocity (geometric)_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 50 (ID: u-component of wind_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 51 (ID: v-component of wind_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 52 (ID: Absolute vorticity_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 53 (ID: 192_7) in 2022 data has no corresponding message in 2014 data.
# Message 54 (ID: Geopotential height_10) in 2022 data corresponds to message 0 in 2014 data.
# Message 55 (ID: Temperature_10) in 2022 data corresponds to message 1 in 2014 data.
# Warning: Message 56 (ID: Relative humidity_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 57 (ID: Specific humidity_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 58 (ID: Vertical velocity (pressure)_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 59 (ID: Vertical velocity (geometric)_10) in 2022 data has no corresponding message in 2014 data.
# Message 60 (ID: u-component of wind_10) in 2022 data corresponds to message 2 in 2014 data.
# Message 61 (ID: v-component of wind_10) in 2022 data corresponds to message 3 in 2014 data.
# Message 62 (ID: Absolute vorticity_10) in 2022 data corresponds to message 4 in 2014 data.
# Message 63 (ID: 192_10) in 2022 data corresponds to message 5 in 2014 data.
# Message 64 (ID: Geopotential height_20) in 2022 data corresponds to message 6 in 2014 data.
# Message 65 (ID: Temperature_20) in 2022 data corresponds to message 7 in 2014 data.
# Warning: Message 66 (ID: Relative humidity_20) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 67 (ID: Specific humidity_20) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 68 (ID: Vertical velocity (pressure)_20) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 69 (ID: Vertical velocity (geometric)_20) in 2022 data has no corresponding message in 2014 data.
# Message 70 (ID: u-component of wind_20) in 2022 data corresponds to message 8 in 2014 data.
# Message 71 (ID: v-component of wind_20) in 2022 data corresponds to message 9 in 2014 data.
# Message 72 (ID: Absolute vorticity_20) in 2022 data corresponds to message 10 in 2014 data.
# Message 73 (ID: 192_20) in 2022 data corresponds to message 11 in 2014 data.
# Warning: Message 74 (ID: Geopotential height_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 75 (ID: Temperature_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 76 (ID: Relative humidity_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 77 (ID: Specific humidity_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 78 (ID: Vertical velocity (pressure)_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 79 (ID: Vertical velocity (geometric)_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 80 (ID: u-component of wind_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 81 (ID: v-component of wind_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 82 (ID: Absolute vorticity_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 83 (ID: 192_40) in 2022 data has no corresponding message in 2014 data.
# Message 84 (ID: Geopotential height_70) in 2022 data corresponds to message 24 in 2014 data.
# Message 85 (ID: Temperature_70) in 2022 data corresponds to message 25 in 2014 data.
# Warning: Message 86 (ID: Relative humidity_70) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 87 (ID: Specific humidity_70) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 88 (ID: Vertical velocity (pressure)_70) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 89 (ID: Vertical velocity (geometric)_70) in 2022 data has no corresponding message in 2014 data.
# Message 90 (ID: u-component of wind_70) in 2022 data corresponds to message 26 in 2014 data.
# Message 91 (ID: v-component of wind_70) in 2022 data corresponds to message 27 in 2014 data.
# Message 92 (ID: Absolute vorticity_70) in 2022 data corresponds to message 28 in 2014 data.
# Message 93 (ID: 192_70) in 2022 data corresponds to message 29 in 2014 data.
# Warning: Message 94 (ID: Geopotential height_1) in 2022 data has no corresponding message in 2014 data.
# Message 95 (ID: Temperature_1) in 2022 data corresponds to message 208 in 2014 data.
# Message 96 (ID: Relative humidity_1) in 2022 data corresponds to message 260 in 2014 data.
# Warning: Message 97 (ID: Specific humidity_1) in 2022 data has no corresponding message in 2014 data.
# Message 98 (ID: Vertical velocity (pressure)_1) in 2022 data corresponds to message 267 in 2014 data.
# Warning: Message 99 (ID: Vertical velocity (geometric)_1) in 2022 data has no corresponding message in 2014 data.
# Message 100 (ID: u-component of wind_1) in 2022 data corresponds to message 265 in 2014 data.
# Message 101 (ID: v-component of wind_1) in 2022 data corresponds to message 266 in 2014 data.
# Warning: Message 102 (ID: Absolute vorticity_1) in 2022 data has no corresponding message in 2014 data.
# Message 103 (ID: 192_1) in 2022 data corresponds to message 209 in 2014 data.
# Message 104 (ID: Geopotential height_2) in 2022 data corresponds to message 279 in 2014 data.
# Message 105 (ID: Temperature_2) in 2022 data corresponds to message 212 in 2014 data.
# Message 106 (ID: Relative humidity_2) in 2022 data corresponds to message 214 in 2014 data.
# Message 107 (ID: Specific humidity_2) in 2022 data corresponds to message 213 in 2014 data.
# Warning: Message 108 (ID: Vertical velocity (pressure)_2) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 109 (ID: Vertical velocity (geometric)_2) in 2022 data has no corresponding message in 2014 data.
# Message 110 (ID: u-component of wind_2) in 2022 data corresponds to message 276 in 2014 data.
# Message 111 (ID: v-component of wind_2) in 2022 data corresponds to message 277 in 2014 data.
# Warning: Message 112 (ID: Absolute vorticity_2) in 2022 data has no corresponding message in 2014 data.
# Message 113 (ID: 192_2) in 2022 data corresponds to message 281 in 2014 data.
# Warning: Message 114 (ID: Geopotential height_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 115 (ID: Temperature_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 116 (ID: Relative humidity_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 117 (ID: Specific humidity_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 118 (ID: Vertical velocity (pressure)_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 119 (ID: Vertical velocity (geometric)_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 120 (ID: u-component of wind_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 121 (ID: v-component of wind_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 122 (ID: Absolute vorticity_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 123 (ID: 192_3) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 124 (ID: Geopotential height_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 125 (ID: Temperature_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 126 (ID: Relative humidity_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 127 (ID: Specific humidity_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 128 (ID: Vertical velocity (pressure)_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 129 (ID: Vertical velocity (geometric)_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 130 (ID: u-component of wind_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 131 (ID: v-component of wind_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 132 (ID: Absolute vorticity_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 133 (ID: 192_5) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 134 (ID: Geopotential height_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 135 (ID: Temperature_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 136 (ID: Relative humidity_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 137 (ID: Specific humidity_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 138 (ID: Vertical velocity (pressure)_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 139 (ID: Vertical velocity (geometric)_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 140 (ID: u-component of wind_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 141 (ID: v-component of wind_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 142 (ID: Absolute vorticity_7) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 143 (ID: 192_7) in 2022 data has no corresponding message in 2014 data.
# Message 144 (ID: Geopotential height_10) in 2022 data corresponds to message 0 in 2014 data.
# Message 145 (ID: Temperature_10) in 2022 data corresponds to message 1 in 2014 data.
# Warning: Message 146 (ID: Relative humidity_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 147 (ID: Specific humidity_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 148 (ID: Vertical velocity (pressure)_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 149 (ID: Vertical velocity (geometric)_10) in 2022 data has no corresponding message in 2014 data.
# Message 150 (ID: u-component of wind_10) in 2022 data corresponds to message 2 in 2014 data.
# Message 151 (ID: v-component of wind_10) in 2022 data corresponds to message 3 in 2014 data.
# Message 152 (ID: Absolute vorticity_10) in 2022 data corresponds to message 4 in 2014 data.
# Message 153 (ID: 192_10) in 2022 data corresponds to message 5 in 2014 data.
# Warning: Message 154 (ID: Geopotential height_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 155 (ID: Temperature_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 156 (ID: Relative humidity_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 157 (ID: Specific humidity_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 158 (ID: Vertical velocity (pressure)_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 159 (ID: Vertical velocity (geometric)_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 160 (ID: u-component of wind_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 161 (ID: v-component of wind_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 162 (ID: Absolute vorticity_15) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 163 (ID: 192_15) in 2022 data has no corresponding message in 2014 data.
# Message 164 (ID: Geopotential height_20) in 2022 data corresponds to message 6 in 2014 data.
# Message 165 (ID: Temperature_20) in 2022 data corresponds to message 7 in 2014 data.
# Warning: Message 166 (ID: Relative humidity_20) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 167 (ID: Specific humidity_20) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 168 (ID: Vertical velocity (pressure)_20) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 169 (ID: Vertical velocity (geometric)_20) in 2022 data has no corresponding message in 2014 data.
# Message 170 (ID: u-component of wind_20) in 2022 data corresponds to message 8 in 2014 data.
# Message 171 (ID: v-component of wind_20) in 2022 data corresponds to message 9 in 2014 data.
# Message 172 (ID: Absolute vorticity_20) in 2022 data corresponds to message 10 in 2014 data.
# Message 173 (ID: 192_20) in 2022 data corresponds to message 11 in 2014 data.
# Message 174 (ID: Geopotential height_30) in 2022 data corresponds to message 12 in 2014 data.
# Message 175 (ID: Temperature_30) in 2022 data corresponds to message 13 in 2014 data.
# Warning: Message 176 (ID: Relative humidity_30) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 177 (ID: Specific humidity_30) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 178 (ID: Vertical velocity (pressure)_30) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 179 (ID: Vertical velocity (geometric)_30) in 2022 data has no corresponding message in 2014 data.
# Message 180 (ID: u-component of wind_30) in 2022 data corresponds to message 14 in 2014 data.
# Message 181 (ID: v-component of wind_30) in 2022 data corresponds to message 15 in 2014 data.
# Message 182 (ID: Absolute vorticity_30) in 2022 data corresponds to message 16 in 2014 data.
# Message 183 (ID: 192_30) in 2022 data corresponds to message 17 in 2014 data.
# Warning: Message 184 (ID: Geopotential height_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 185 (ID: Temperature_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 186 (ID: Relative humidity_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 187 (ID: Specific humidity_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 188 (ID: Vertical velocity (pressure)_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 189 (ID: Vertical velocity (geometric)_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 190 (ID: u-component of wind_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 191 (ID: v-component of wind_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 192 (ID: Absolute vorticity_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 193 (ID: 192_40) in 2022 data has no corresponding message in 2014 data.
# Message 194 (ID: Geopotential height_50) in 2022 data corresponds to message 18 in 2014 data.
# Message 195 (ID: Temperature_50) in 2022 data corresponds to message 19 in 2014 data.
# Warning: Message 196 (ID: Relative humidity_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 197 (ID: Total cloud cover_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 198 (ID: Specific humidity_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 199 (ID: Vertical velocity (pressure)_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 200 (ID: Vertical velocity (geometric)_50) in 2022 data has no corresponding message in 2014 data.
# Message 201 (ID: u-component of wind_50) in 2022 data corresponds to message 20 in 2014 data.
# Message 202 (ID: v-component of wind_50) in 2022 data corresponds to message 21 in 2014 data.
# Message 203 (ID: Absolute vorticity_50) in 2022 data corresponds to message 22 in 2014 data.
# Warning: Message 204 (ID: Cloud mixing ratio_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 205 (ID: Ice water mixing ratio_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 206 (ID: Rain mixing ratio_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 207 (ID: Snow mixing ratio_50) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 208 (ID: Graupel (snow pellets)_50) in 2022 data has no corresponding message in 2014 data.
# Message 209 (ID: 192_50) in 2022 data corresponds to message 23 in 2014 data.
# Message 210 (ID: Geopotential height_70) in 2022 data corresponds to message 24 in 2014 data.
# Message 211 (ID: Temperature_70) in 2022 data corresponds to message 25 in 2014 data.
# Warning: Message 212 (ID: Relative humidity_70) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 213 (ID: Specific humidity_70) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 214 (ID: Vertical velocity (pressure)_70) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 215 (ID: Vertical velocity (geometric)_70) in 2022 data has no corresponding message in 2014 data.
# Message 216 (ID: u-component of wind_70) in 2022 data corresponds to message 26 in 2014 data.
# Message 217 (ID: v-component of wind_70) in 2022 data corresponds to message 27 in 2014 data.
# Message 218 (ID: Absolute vorticity_70) in 2022 data corresponds to message 28 in 2014 data.
# Message 219 (ID: 192_70) in 2022 data corresponds to message 29 in 2014 data.
# Message 220 (ID: Geopotential height_100) in 2022 data corresponds to message 30 in 2014 data.
# Message 221 (ID: Temperature_100) in 2022 data corresponds to message 31 in 2014 data.
# Message 222 (ID: Relative humidity_100) in 2022 data corresponds to message 32 in 2014 data.
# Warning: Message 223 (ID: Total cloud cover_100) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 224 (ID: Specific humidity_100) in 2022 data has no corresponding message in 2014 data.
# Message 225 (ID: Vertical velocity (pressure)_100) in 2022 data corresponds to message 33 in 2014 data.
# Warning: Message 226 (ID: Vertical velocity (geometric)_100) in 2022 data has no corresponding message in 2014 data.
# Message 227 (ID: u-component of wind_100) in 2022 data corresponds to message 34 in 2014 data.
# Message 228 (ID: v-component of wind_100) in 2022 data corresponds to message 35 in 2014 data.
# Message 229 (ID: Absolute vorticity_100) in 2022 data corresponds to message 36 in 2014 data.
# Message 230 (ID: Cloud mixing ratio_100) in 2022 data corresponds to message 37 in 2014 data.
# Warning: Message 231 (ID: Ice water mixing ratio_100) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 232 (ID: Rain mixing ratio_100) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 233 (ID: Snow mixing ratio_100) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 234 (ID: Graupel (snow pellets)_100) in 2022 data has no corresponding message in 2014 data.
# Message 235 (ID: 192_100) in 2022 data corresponds to message 38 in 2014 data.
# Message 236 (ID: Geopotential height_150) in 2022 data corresponds to message 39 in 2014 data.
# Message 237 (ID: Temperature_150) in 2022 data corresponds to message 40 in 2014 data.
# Message 238 (ID: Relative humidity_150) in 2022 data corresponds to message 41 in 2014 data.
# Warning: Message 239 (ID: Total cloud cover_150) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 240 (ID: Specific humidity_150) in 2022 data has no corresponding message in 2014 data.
# Message 241 (ID: Vertical velocity (pressure)_150) in 2022 data corresponds to message 42 in 2014 data.
# Warning: Message 242 (ID: Vertical velocity (geometric)_150) in 2022 data has no corresponding message in 2014 data.
# Message 243 (ID: u-component of wind_150) in 2022 data corresponds to message 43 in 2014 data.
# Message 244 (ID: v-component of wind_150) in 2022 data corresponds to message 44 in 2014 data.
# Message 245 (ID: Absolute vorticity_150) in 2022 data corresponds to message 45 in 2014 data.
# Message 246 (ID: Cloud mixing ratio_150) in 2022 data corresponds to message 46 in 2014 data.
# Warning: Message 247 (ID: Ice water mixing ratio_150) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 248 (ID: Rain mixing ratio_150) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 249 (ID: Snow mixing ratio_150) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 250 (ID: Graupel (snow pellets)_150) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 251 (ID: 192_150) in 2022 data has no corresponding message in 2014 data.
# Message 252 (ID: Geopotential height_200) in 2022 data corresponds to message 47 in 2014 data.
# Message 253 (ID: Temperature_200) in 2022 data corresponds to message 48 in 2014 data.
# Message 254 (ID: Relative humidity_200) in 2022 data corresponds to message 49 in 2014 data.
# Warning: Message 255 (ID: Total cloud cover_200) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 256 (ID: Specific humidity_200) in 2022 data has no corresponding message in 2014 data.
# Message 257 (ID: Vertical velocity (pressure)_200) in 2022 data corresponds to message 50 in 2014 data.
# Warning: Message 258 (ID: Vertical velocity (geometric)_200) in 2022 data has no corresponding message in 2014 data.
# Message 259 (ID: u-component of wind_200) in 2022 data corresponds to message 51 in 2014 data.
# Message 260 (ID: v-component of wind_200) in 2022 data corresponds to message 52 in 2014 data.
# Message 261 (ID: Absolute vorticity_200) in 2022 data corresponds to message 53 in 2014 data.
# Message 262 (ID: Cloud mixing ratio_200) in 2022 data corresponds to message 54 in 2014 data.
# Warning: Message 263 (ID: Ice water mixing ratio_200) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 264 (ID: Rain mixing ratio_200) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 265 (ID: Snow mixing ratio_200) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 266 (ID: Graupel (snow pellets)_200) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 267 (ID: 192_200) in 2022 data has no corresponding message in 2014 data.
# Message 268 (ID: Geopotential height_250) in 2022 data corresponds to message 55 in 2014 data.
# Message 269 (ID: Temperature_250) in 2022 data corresponds to message 56 in 2014 data.
# Message 270 (ID: Relative humidity_250) in 2022 data corresponds to message 57 in 2014 data.
# Warning: Message 271 (ID: Total cloud cover_250) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 272 (ID: Specific humidity_250) in 2022 data has no corresponding message in 2014 data.
# Message 273 (ID: Vertical velocity (pressure)_250) in 2022 data corresponds to message 58 in 2014 data.
# Warning: Message 274 (ID: Vertical velocity (geometric)_250) in 2022 data has no corresponding message in 2014 data.
# Message 275 (ID: u-component of wind_250) in 2022 data corresponds to message 59 in 2014 data.
# Message 276 (ID: v-component of wind_250) in 2022 data corresponds to message 60 in 2014 data.
# Message 277 (ID: Absolute vorticity_250) in 2022 data corresponds to message 61 in 2014 data.
# Message 278 (ID: Cloud mixing ratio_250) in 2022 data corresponds to message 62 in 2014 data.
# Warning: Message 279 (ID: Ice water mixing ratio_250) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 280 (ID: Rain mixing ratio_250) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 281 (ID: Snow mixing ratio_250) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 282 (ID: Graupel (snow pellets)_250) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 283 (ID: 192_250) in 2022 data has no corresponding message in 2014 data.
# Message 284 (ID: Geopotential height_300) in 2022 data corresponds to message 63 in 2014 data.
# Message 285 (ID: Temperature_300) in 2022 data corresponds to message 64 in 2014 data.
# Message 286 (ID: Relative humidity_300) in 2022 data corresponds to message 65 in 2014 data.
# Warning: Message 287 (ID: Total cloud cover_300) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 288 (ID: Specific humidity_300) in 2022 data has no corresponding message in 2014 data.
# Message 289 (ID: Vertical velocity (pressure)_300) in 2022 data corresponds to message 66 in 2014 data.
# Warning: Message 290 (ID: Vertical velocity (geometric)_300) in 2022 data has no corresponding message in 2014 data.
# Message 291 (ID: u-component of wind_300) in 2022 data corresponds to message 67 in 2014 data.
# Message 292 (ID: v-component of wind_300) in 2022 data corresponds to message 68 in 2014 data.
# Message 293 (ID: Absolute vorticity_300) in 2022 data corresponds to message 69 in 2014 data.
# Message 294 (ID: Cloud mixing ratio_300) in 2022 data corresponds to message 70 in 2014 data.
# Warning: Message 295 (ID: Ice water mixing ratio_300) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 296 (ID: Rain mixing ratio_300) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 297 (ID: Snow mixing ratio_300) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 298 (ID: Graupel (snow pellets)_300) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 299 (ID: 192_300) in 2022 data has no corresponding message in 2014 data.
# Message 300 (ID: Geopotential height_350) in 2022 data corresponds to message 71 in 2014 data.
# Message 301 (ID: Temperature_350) in 2022 data corresponds to message 72 in 2014 data.
# Message 302 (ID: Relative humidity_350) in 2022 data corresponds to message 73 in 2014 data.
# Warning: Message 303 (ID: Total cloud cover_350) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 304 (ID: Specific humidity_350) in 2022 data has no corresponding message in 2014 data.
# Message 305 (ID: Vertical velocity (pressure)_350) in 2022 data corresponds to message 74 in 2014 data.
# Warning: Message 306 (ID: Vertical velocity (geometric)_350) in 2022 data has no corresponding message in 2014 data.
# Message 307 (ID: u-component of wind_350) in 2022 data corresponds to message 75 in 2014 data.
# Message 308 (ID: v-component of wind_350) in 2022 data corresponds to message 76 in 2014 data.
# Message 309 (ID: Absolute vorticity_350) in 2022 data corresponds to message 77 in 2014 data.
# Message 310 (ID: Cloud mixing ratio_350) in 2022 data corresponds to message 78 in 2014 data.
# Warning: Message 311 (ID: Ice water mixing ratio_350) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 312 (ID: Rain mixing ratio_350) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 313 (ID: Snow mixing ratio_350) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 314 (ID: Graupel (snow pellets)_350) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 315 (ID: 192_350) in 2022 data has no corresponding message in 2014 data.
# Message 316 (ID: Geopotential height_400) in 2022 data corresponds to message 79 in 2014 data.
# Message 317 (ID: Temperature_400) in 2022 data corresponds to message 80 in 2014 data.
# Message 318 (ID: Relative humidity_400) in 2022 data corresponds to message 81 in 2014 data.
# Warning: Message 319 (ID: Total cloud cover_400) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 320 (ID: Specific humidity_400) in 2022 data has no corresponding message in 2014 data.
# Message 321 (ID: Vertical velocity (pressure)_400) in 2022 data corresponds to message 82 in 2014 data.
# Warning: Message 322 (ID: Vertical velocity (geometric)_400) in 2022 data has no corresponding message in 2014 data.
# Message 323 (ID: u-component of wind_400) in 2022 data corresponds to message 83 in 2014 data.
# Message 324 (ID: v-component of wind_400) in 2022 data corresponds to message 84 in 2014 data.
# Message 325 (ID: Absolute vorticity_400) in 2022 data corresponds to message 85 in 2014 data.
# Message 326 (ID: Cloud mixing ratio_400) in 2022 data corresponds to message 86 in 2014 data.
# Warning: Message 327 (ID: Ice water mixing ratio_400) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 328 (ID: Rain mixing ratio_400) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 329 (ID: Snow mixing ratio_400) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 330 (ID: Graupel (snow pellets)_400) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 331 (ID: 192_400) in 2022 data has no corresponding message in 2014 data.
# Message 332 (ID: Geopotential height_450) in 2022 data corresponds to message 87 in 2014 data.
# Message 333 (ID: Temperature_450) in 2022 data corresponds to message 88 in 2014 data.
# Message 334 (ID: Relative humidity_450) in 2022 data corresponds to message 89 in 2014 data.
# Warning: Message 335 (ID: Total cloud cover_450) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 336 (ID: Specific humidity_450) in 2022 data has no corresponding message in 2014 data.
# Message 337 (ID: Vertical velocity (pressure)_450) in 2022 data corresponds to message 90 in 2014 data.
# Warning: Message 338 (ID: Vertical velocity (geometric)_450) in 2022 data has no corresponding message in 2014 data.
# Message 339 (ID: u-component of wind_450) in 2022 data corresponds to message 91 in 2014 data.
# Message 340 (ID: v-component of wind_450) in 2022 data corresponds to message 92 in 2014 data.
# Message 341 (ID: Absolute vorticity_450) in 2022 data corresponds to message 93 in 2014 data.
# Message 342 (ID: Cloud mixing ratio_450) in 2022 data corresponds to message 94 in 2014 data.
# Warning: Message 343 (ID: Ice water mixing ratio_450) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 344 (ID: Rain mixing ratio_450) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 345 (ID: Snow mixing ratio_450) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 346 (ID: Graupel (snow pellets)_450) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 347 (ID: 192_450) in 2022 data has no corresponding message in 2014 data.
# Message 348 (ID: Geopotential height_500) in 2022 data corresponds to message 95 in 2014 data.
# Message 349 (ID: Temperature_500) in 2022 data corresponds to message 96 in 2014 data.
# Message 350 (ID: Relative humidity_500) in 2022 data corresponds to message 97 in 2014 data.
# Warning: Message 351 (ID: Total cloud cover_500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 352 (ID: Specific humidity_500) in 2022 data has no corresponding message in 2014 data.
# Message 353 (ID: Vertical velocity (pressure)_500) in 2022 data corresponds to message 98 in 2014 data.
# Warning: Message 354 (ID: Vertical velocity (geometric)_500) in 2022 data has no corresponding message in 2014 data.
# Message 355 (ID: u-component of wind_500) in 2022 data corresponds to message 99 in 2014 data.
# Message 356 (ID: v-component of wind_500) in 2022 data corresponds to message 100 in 2014 data.
# Message 357 (ID: Absolute vorticity_500) in 2022 data corresponds to message 101 in 2014 data.
# Message 358 (ID: Cloud mixing ratio_500) in 2022 data corresponds to message 102 in 2014 data.
# Warning: Message 359 (ID: Ice water mixing ratio_500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 360 (ID: Rain mixing ratio_500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 361 (ID: Snow mixing ratio_500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 362 (ID: Graupel (snow pellets)_500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 363 (ID: 192_500) in 2022 data has no corresponding message in 2014 data.
# Message 364 (ID: Geopotential height_550) in 2022 data corresponds to message 103 in 2014 data.
# Message 365 (ID: Temperature_550) in 2022 data corresponds to message 104 in 2014 data.
# Message 366 (ID: Relative humidity_550) in 2022 data corresponds to message 105 in 2014 data.
# Warning: Message 367 (ID: Total cloud cover_550) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 368 (ID: Specific humidity_550) in 2022 data has no corresponding message in 2014 data.
# Message 369 (ID: Vertical velocity (pressure)_550) in 2022 data corresponds to message 106 in 2014 data.
# Warning: Message 370 (ID: Vertical velocity (geometric)_550) in 2022 data has no corresponding message in 2014 data.
# Message 371 (ID: u-component of wind_550) in 2022 data corresponds to message 107 in 2014 data.
# Message 372 (ID: v-component of wind_550) in 2022 data corresponds to message 108 in 2014 data.
# Message 373 (ID: Absolute vorticity_550) in 2022 data corresponds to message 109 in 2014 data.
# Message 374 (ID: Cloud mixing ratio_550) in 2022 data corresponds to message 110 in 2014 data.
# Warning: Message 375 (ID: Ice water mixing ratio_550) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 376 (ID: Rain mixing ratio_550) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 377 (ID: Snow mixing ratio_550) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 378 (ID: Graupel (snow pellets)_550) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 379 (ID: 192_550) in 2022 data has no corresponding message in 2014 data.
# Message 380 (ID: Geopotential height_600) in 2022 data corresponds to message 111 in 2014 data.
# Message 381 (ID: Temperature_600) in 2022 data corresponds to message 112 in 2014 data.
# Message 382 (ID: Relative humidity_600) in 2022 data corresponds to message 113 in 2014 data.
# Warning: Message 383 (ID: Total cloud cover_600) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 384 (ID: Specific humidity_600) in 2022 data has no corresponding message in 2014 data.
# Message 385 (ID: Vertical velocity (pressure)_600) in 2022 data corresponds to message 114 in 2014 data.
# Warning: Message 386 (ID: Vertical velocity (geometric)_600) in 2022 data has no corresponding message in 2014 data.
# Message 387 (ID: u-component of wind_600) in 2022 data corresponds to message 115 in 2014 data.
# Message 388 (ID: v-component of wind_600) in 2022 data corresponds to message 116 in 2014 data.
# Message 389 (ID: Absolute vorticity_600) in 2022 data corresponds to message 117 in 2014 data.
# Message 390 (ID: Cloud mixing ratio_600) in 2022 data corresponds to message 118 in 2014 data.
# Warning: Message 391 (ID: Ice water mixing ratio_600) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 392 (ID: Rain mixing ratio_600) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 393 (ID: Snow mixing ratio_600) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 394 (ID: Graupel (snow pellets)_600) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 395 (ID: 192_600) in 2022 data has no corresponding message in 2014 data.
# Message 396 (ID: Geopotential height_650) in 2022 data corresponds to message 119 in 2014 data.
# Message 397 (ID: Temperature_650) in 2022 data corresponds to message 120 in 2014 data.
# Message 398 (ID: Relative humidity_650) in 2022 data corresponds to message 121 in 2014 data.
# Warning: Message 399 (ID: Total cloud cover_650) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 400 (ID: Specific humidity_650) in 2022 data has no corresponding message in 2014 data.
# Message 401 (ID: Vertical velocity (pressure)_650) in 2022 data corresponds to message 122 in 2014 data.
# Warning: Message 402 (ID: Vertical velocity (geometric)_650) in 2022 data has no corresponding message in 2014 data.
# Message 403 (ID: u-component of wind_650) in 2022 data corresponds to message 123 in 2014 data.
# Message 404 (ID: v-component of wind_650) in 2022 data corresponds to message 124 in 2014 data.
# Message 405 (ID: Absolute vorticity_650) in 2022 data corresponds to message 125 in 2014 data.
# Message 406 (ID: Cloud mixing ratio_650) in 2022 data corresponds to message 126 in 2014 data.
# Warning: Message 407 (ID: Ice water mixing ratio_650) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 408 (ID: Rain mixing ratio_650) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 409 (ID: Snow mixing ratio_650) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 410 (ID: Graupel (snow pellets)_650) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 411 (ID: 192_650) in 2022 data has no corresponding message in 2014 data.
# Message 412 (ID: Geopotential height_700) in 2022 data corresponds to message 127 in 2014 data.
# Message 413 (ID: Temperature_700) in 2022 data corresponds to message 128 in 2014 data.
# Message 414 (ID: Relative humidity_700) in 2022 data corresponds to message 129 in 2014 data.
# Warning: Message 415 (ID: Total cloud cover_700) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 416 (ID: Specific humidity_700) in 2022 data has no corresponding message in 2014 data.
# Message 417 (ID: Vertical velocity (pressure)_700) in 2022 data corresponds to message 130 in 2014 data.
# Warning: Message 418 (ID: Vertical velocity (geometric)_700) in 2022 data has no corresponding message in 2014 data.
# Message 419 (ID: u-component of wind_700) in 2022 data corresponds to message 131 in 2014 data.
# Message 420 (ID: v-component of wind_700) in 2022 data corresponds to message 132 in 2014 data.
# Message 421 (ID: Absolute vorticity_700) in 2022 data corresponds to message 133 in 2014 data.
# Message 422 (ID: Cloud mixing ratio_700) in 2022 data corresponds to message 134 in 2014 data.
# Warning: Message 423 (ID: Ice water mixing ratio_700) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 424 (ID: Rain mixing ratio_700) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 425 (ID: Snow mixing ratio_700) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 426 (ID: Graupel (snow pellets)_700) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 427 (ID: 192_700) in 2022 data has no corresponding message in 2014 data.
# Message 428 (ID: Geopotential height_750) in 2022 data corresponds to message 135 in 2014 data.
# Message 429 (ID: Temperature_750) in 2022 data corresponds to message 136 in 2014 data.
# Message 430 (ID: Relative humidity_750) in 2022 data corresponds to message 137 in 2014 data.
# Warning: Message 431 (ID: Total cloud cover_750) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 432 (ID: Specific humidity_750) in 2022 data has no corresponding message in 2014 data.
# Message 433 (ID: Vertical velocity (pressure)_750) in 2022 data corresponds to message 138 in 2014 data.
# Warning: Message 434 (ID: Vertical velocity (geometric)_750) in 2022 data has no corresponding message in 2014 data.
# Message 435 (ID: u-component of wind_750) in 2022 data corresponds to message 139 in 2014 data.
# Message 436 (ID: v-component of wind_750) in 2022 data corresponds to message 140 in 2014 data.
# Message 437 (ID: Absolute vorticity_750) in 2022 data corresponds to message 141 in 2014 data.
# Message 438 (ID: Cloud mixing ratio_750) in 2022 data corresponds to message 142 in 2014 data.
# Warning: Message 439 (ID: Ice water mixing ratio_750) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 440 (ID: Rain mixing ratio_750) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 441 (ID: Snow mixing ratio_750) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 442 (ID: Graupel (snow pellets)_750) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 443 (ID: 192_750) in 2022 data has no corresponding message in 2014 data.
# Message 444 (ID: Geopotential height_800) in 2022 data corresponds to message 143 in 2014 data.
# Message 445 (ID: Temperature_800) in 2022 data corresponds to message 144 in 2014 data.
# Message 446 (ID: Relative humidity_800) in 2022 data corresponds to message 145 in 2014 data.
# Warning: Message 447 (ID: Total cloud cover_800) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 448 (ID: Specific humidity_800) in 2022 data has no corresponding message in 2014 data.
# Message 449 (ID: Vertical velocity (pressure)_800) in 2022 data corresponds to message 146 in 2014 data.
# Warning: Message 450 (ID: Vertical velocity (geometric)_800) in 2022 data has no corresponding message in 2014 data.
# Message 451 (ID: u-component of wind_800) in 2022 data corresponds to message 147 in 2014 data.
# Message 452 (ID: v-component of wind_800) in 2022 data corresponds to message 148 in 2014 data.
# Message 453 (ID: Absolute vorticity_800) in 2022 data corresponds to message 149 in 2014 data.
# Message 454 (ID: Cloud mixing ratio_800) in 2022 data corresponds to message 150 in 2014 data.
# Warning: Message 455 (ID: Ice water mixing ratio_800) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 456 (ID: Rain mixing ratio_800) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 457 (ID: Snow mixing ratio_800) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 458 (ID: Graupel (snow pellets)_800) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 459 (ID: 192_800) in 2022 data has no corresponding message in 2014 data.
# Message 460 (ID: Geopotential height_850) in 2022 data corresponds to message 151 in 2014 data.
# Message 461 (ID: Temperature_850) in 2022 data corresponds to message 152 in 2014 data.
# Message 462 (ID: Relative humidity_850) in 2022 data corresponds to message 153 in 2014 data.
# Warning: Message 463 (ID: Total cloud cover_850) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 464 (ID: Specific humidity_850) in 2022 data has no corresponding message in 2014 data.
# Message 465 (ID: Vertical velocity (pressure)_850) in 2022 data corresponds to message 154 in 2014 data.
# Warning: Message 466 (ID: Vertical velocity (geometric)_850) in 2022 data has no corresponding message in 2014 data.
# Message 467 (ID: u-component of wind_850) in 2022 data corresponds to message 155 in 2014 data.
# Message 468 (ID: v-component of wind_850) in 2022 data corresponds to message 156 in 2014 data.
# Message 469 (ID: Absolute vorticity_850) in 2022 data corresponds to message 157 in 2014 data.
# Message 470 (ID: Cloud mixing ratio_850) in 2022 data corresponds to message 158 in 2014 data.
# Warning: Message 471 (ID: Ice water mixing ratio_850) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 472 (ID: Rain mixing ratio_850) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 473 (ID: Snow mixing ratio_850) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 474 (ID: Graupel (snow pellets)_850) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 475 (ID: 192_850) in 2022 data has no corresponding message in 2014 data.
# Message 476 (ID: Geopotential height_900) in 2022 data corresponds to message 159 in 2014 data.
# Message 477 (ID: Temperature_900) in 2022 data corresponds to message 160 in 2014 data.
# Message 478 (ID: Relative humidity_900) in 2022 data corresponds to message 161 in 2014 data.
# ...
# Message 530 (ID: Vertical velocity (pressure)_975) in 2022 data corresponds to message 186 in 2014 data.
# Warning: Message 531 (ID: Vertical velocity (geometric)_975) in 2022 data has no corresponding message in 2014 data.
# Message 532 (ID: u-component of wind_975) in 2022 data corresponds to message 187 in 2014 data.
# Message 533 (ID: v-component of wind_975) in 2022 data corresponds to message 188 in 2014 data.
# Message 534 (ID: Absolute vorticity_975) in 2022 data corresponds to message 189 in 2014 data.
# Message 535 (ID: Cloud mixing ratio_975) in 2022 data corresponds to message 190 in 2014 data.
# Warning: Message 536 (ID: Ice water mixing ratio_975) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 537 (ID: Rain mixing ratio_975) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 538 (ID: Snow mixing ratio_975) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 539 (ID: Graupel (snow pellets)_975) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 540 (ID: 192_975) in 2022 data has no corresponding message in 2014 data.
# Message 541 (ID: Temperature_1000) in 2022 data corresponds to message 192 in 2014 data.
# Message 542 (ID: Relative humidity_1000) in 2022 data corresponds to message 193 in 2014 data.
# Warning: Message 543 (ID: Total cloud cover_1000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 544 (ID: Specific humidity_1000) in 2022 data has no corresponding message in 2014 data.
# Message 545 (ID: Vertical velocity (pressure)_1000) in 2022 data corresponds to message 194 in 2014 data.
# Warning: Message 546 (ID: Vertical velocity (geometric)_1000) in 2022 data has no corresponding message in 2014 data.
# Message 547 (ID: u-component of wind_1000) in 2022 data corresponds to message 195 in 2014 data.
# Message 548 (ID: v-component of wind_1000) in 2022 data corresponds to message 196 in 2014 data.
# Message 549 (ID: Absolute vorticity_1000) in 2022 data corresponds to message 197 in 2014 data.
# Message 550 (ID: Cloud mixing ratio_1000) in 2022 data corresponds to message 198 in 2014 data.
# Warning: Message 551 (ID: Ice water mixing ratio_1000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 552 (ID: Rain mixing ratio_1000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 553 (ID: Snow mixing ratio_1000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 554 (ID: Graupel (snow pellets)_1000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 555 (ID: 192_1000) in 2022 data has no corresponding message in 2014 data.
# Message 556 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Message 557 (ID: Geopotential height_1000) in 2022 data corresponds to message 191 in 2014 data.
# Warning: Message 558 (ID: 195_4000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 559 (ID: 195_1000) in 2022 data has no corresponding message in 2014 data.
# Message 560 (ID: Pressure_0) in 2022 data corresponds to message 199 in 2014 data.
# Message 561 (ID: Geopotential height_0) in 2022 data corresponds to message 200 in 2014 data.
# Message 562 (ID: Temperature_0) in 2022 data corresponds to message 201 in 2014 data.
# Warning: Message 563 (ID: Soil temperature_0) in 2022 data has no corresponding message in 2014 data.
# Message 564 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Message 565 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Warning: Message 566 (ID: Soil temperature_0) in 2022 data has no corresponding message in 2014 data.
# Message 567 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Message 568 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Warning: Message 569 (ID: Soil temperature_0) in 2022 data has no corresponding message in 2014 data.
# Message 570 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Message 571 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Warning: Message 572 (ID: Soil temperature_1) in 2022 data has no corresponding message in 2014 data.
# Message 573 (ID: 192_1) in 2022 data corresponds to message 209 in 2014 data.
# Message 574 (ID: 192_1) in 2022 data corresponds to message 209 in 2014 data.
# Message 575 (ID: 196_0) in 2022 data corresponds to message 257 in 2014 data.
# Message 576 (ID: Water equivalent of accumulated snow depth_0) in 2022 data corresponds to message 210 in 2014 data.
# Warning: Message 577 (ID: Snow depth_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 578 (ID: Ice thickness_0) in 2022 data has no corresponding message in 2014 data.
# Message 579 (ID: Temperature_2) in 2022 data corresponds to message 212 in 2014 data.
# Message 580 (ID: Specific humidity_2) in 2022 data corresponds to message 213 in 2014 data.
# Warning: Message 581 (ID: Dew point temperature_2) in 2022 data has no corresponding message in 2014 data.
# Message 582 (ID: Relative humidity_2) in 2022 data corresponds to message 214 in 2014 data.
# Warning: Message 583 (ID: 21_2) in 2022 data has no corresponding message in 2014 data.
# Message 584 (ID: u-component of wind_10) in 2022 data corresponds to message 2 in 2014 data.
# Message 585 (ID: v-component of wind_10) in 2022 data corresponds to message 3 in 2014 data.
# Warning: Message 586 (ID: Ice growth rate_10) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 587 (ID: Percent frozen precipitation_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 588 (ID: Precipitation rate_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 589 (ID: 195_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 590 (ID: 194_0) in 2022 data has no corresponding message in 2014 data.
# Message 591 (ID: 193_0) in 2022 data corresponds to message 254 in 2014 data.
# Message 592 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Warning: Message 593 (ID: Surface roughness_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 594 (ID: 197_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 595 (ID: Vegetation_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 596 (ID: Soil type_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 597 (ID: 201_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 598 (ID: 203_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 599 (ID: 201_0) in 2022 data has no corresponding message in 2014 data.
# Message 600 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Message 601 (ID: Convective available potential energy_0) in 2022 data corresponds to message 218 in 2014 data.
# Message 602 (ID: Convective inhibition_0) in 2022 data corresponds to message 219 in 2014 data.
# Message 603 (ID: Precipitable water_0) in 2022 data corresponds to message 220 in 2014 data.
# Message 604 (ID: Cloud water_0) in 2022 data corresponds to message 221 in 2014 data.
# Message 605 (ID: Relative humidity_0) in 2022 data corresponds to message 222 in 2014 data.
# Message 606 (ID: Total ozone_0) in 2022 data corresponds to message 223 in 2014 data.
# Warning: Message 607 (ID: Low cloud cover_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 608 (ID: Medium cloud cover_0) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 609 (ID: High cloud cover_0) in 2022 data has no corresponding message in 2014 data.
# Message 610 (ID: Total cloud cover_0) in 2022 data corresponds to message 224 in 2014 data.
# Message 611 (ID: Geopotential height_0) in 2022 data corresponds to message 200 in 2014 data.
# Warning: Message 612 (ID: Storm relative helicity_3000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 613 (ID: 194_6000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 614 (ID: 195_6000) in 2022 data has no corresponding message in 2014 data.
# Message 615 (ID: Pressure_0) in 2022 data corresponds to message 199 in 2014 data.
# Warning: Message 616 (ID: ICAO Standard Atmosphere Reference Height_0) in 2022 data has no corresponding message in 2014 data.
# Message 617 (ID: Geopotential height_0) in 2022 data corresponds to message 200 in 2014 data.
# Message 618 (ID: Temperature_0) in 2022 data corresponds to message 201 in 2014 data.
# Message 619 (ID: u-component of wind_0) in 2022 data corresponds to message 228 in 2014 data.
# Message 620 (ID: v-component of wind_0) in 2022 data corresponds to message 229 in 2014 data.
# Message 621 (ID: 192_0) in 2022 data corresponds to message 203 in 2014 data.
# Message 622 (ID: Pressure_0) in 2022 data corresponds to message 199 in 2014 data.
# Warning: Message 623 (ID: ICAO Standard Atmosphere Reference Height_0) in 2022 data has no corresponding message in 2014 data.
# Message 624 (ID: Geopotential height_0) in 2022 data corresponds to message 200 in 2014 data.
# Message 625 (ID: u-component of wind_0) in 2022 data corresponds to message 228 in 2014 data.
# Message 626 (ID: v-component of wind_0) in 2022 data corresponds to message 229 in 2014 data.
# Message 627 (ID: Temperature_0) in 2022 data corresponds to message 201 in 2014 data.
# Message 628 (ID: u-component of wind_20) in 2022 data corresponds to message 8 in 2014 data.
# Message 629 (ID: v-component of wind_20) in 2022 data corresponds to message 9 in 2014 data.
# Message 630 (ID: u-component of wind_30) in 2022 data corresponds to message 14 in 2014 data.
# Message 631 (ID: v-component of wind_30) in 2022 data corresponds to message 15 in 2014 data.
# Warning: Message 632 (ID: u-component of wind_40) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 633 (ID: v-component of wind_40) in 2022 data has no corresponding message in 2014 data.
# Message 634 (ID: u-component of wind_50) in 2022 data corresponds to message 20 in 2014 data.
# Message 635 (ID: v-component of wind_50) in 2022 data corresponds to message 21 in 2014 data.
# Warning: Message 636 (ID: Temperature_80) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 637 (ID: Specific humidity_80) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 638 (ID: Pressure_80) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 639 (ID: u-component of wind_80) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 640 (ID: v-component of wind_80) in 2022 data has no corresponding message in 2014 data.
# Message 641 (ID: Temperature_100) in 2022 data corresponds to message 31 in 2014 data.
# Message 642 (ID: u-component of wind_100) in 2022 data corresponds to message 34 in 2014 data.
# Message 643 (ID: v-component of wind_100) in 2022 data corresponds to message 35 in 2014 data.
# Warning: Message 644 (ID: Temperature_1829) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 645 (ID: u-component of wind_1829) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 646 (ID: v-component of wind_1829) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 647 (ID: Temperature_2743) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 648 (ID: u-component of wind_2743) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 649 (ID: v-component of wind_2743) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 650 (ID: Temperature_3658) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 651 (ID: u-component of wind_3658) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 652 (ID: v-component of wind_3658) in 2022 data has no corresponding message in 2014 data.
# Message 653 (ID: Geopotential height_0) in 2022 data corresponds to message 200 in 2014 data.
# Message 654 (ID: Relative humidity_0) in 2022 data corresponds to message 222 in 2014 data.
# Message 655 (ID: Geopotential height_0) in 2022 data corresponds to message 200 in 2014 data.
# Message 656 (ID: Relative humidity_0) in 2022 data corresponds to message 222 in 2014 data.
# Message 657 (ID: Temperature_3000) in 2022 data corresponds to message 249 in 2014 data.
# Message 658 (ID: Relative humidity_3000) in 2022 data corresponds to message 250 in 2014 data.
# Message 659 (ID: Specific humidity_3000) in 2022 data corresponds to message 251 in 2014 data.
# Message 660 (ID: u-component of wind_3000) in 2022 data corresponds to message 252 in 2014 data.
# Message 661 (ID: v-component of wind_3000) in 2022 data corresponds to message 253 in 2014 data.
# Message 662 (ID: 193_0) in 2022 data corresponds to message 254 in 2014 data.
# Message 663 (ID: Convective available potential energy_18000) in 2022 data corresponds to message 255 in 2014 data.
# Message 664 (ID: Convective inhibition_18000) in 2022 data corresponds to message 256 in 2014 data.
# Message 665 (ID: 196_0) in 2022 data corresponds to message 257 in 2014 data.
# Message 666 (ID: Relative humidity_0) in 2022 data corresponds to message 222 in 2014 data.
# Message 667 (ID: Relative humidity_0) in 2022 data corresponds to message 222 in 2014 data.
# Message 668 (ID: Relative humidity_1) in 2022 data corresponds to message 260 in 2014 data.
# Message 669 (ID: Relative humidity_0) in 2022 data corresponds to message 222 in 2014 data.
# Message 670 (ID: Temperature_1) in 2022 data corresponds to message 208 in 2014 data.
# Message 671 (ID: Potential temperature_1) in 2022 data corresponds to message 263 in 2014 data.
# Message 672 (ID: Relative humidity_1) in 2022 data corresponds to message 260 in 2014 data.
# Message 673 (ID: u-component of wind_1) in 2022 data corresponds to message 265 in 2014 data.
# Message 674 (ID: v-component of wind_1) in 2022 data corresponds to message 266 in 2014 data.
# Message 675 (ID: Vertical velocity (pressure)_1) in 2022 data corresponds to message 267 in 2014 data.
# Warning: Message 676 (ID: Convective available potential energy_9000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 677 (ID: Convective inhibition_9000) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 678 (ID: Convective available potential energy_25500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 679 (ID: Convective inhibition_25500) in 2022 data has no corresponding message in 2014 data.
# Warning: Message 680 (ID: 200_25500) in 2022 data has no corresponding message in 2014 data.
# Message 681 (ID: Land cover (0=land, 1=sea)_0) in 2022 data corresponds to message 268 in 2014 data.
# Message 682 (ID: Ice cover_0) in 2022 data corresponds to message 269 in 2014 data.
# Warning: Message 683 (ID: 8_0) in 2022 data has no corresponding message in 2014 data.
# Message 684 (ID: u-component of wind_2) in 2022 data corresponds to message 276 in 2014 data.
# Message 685 (ID: v-component of wind_2) in 2022 data corresponds to message 277 in 2014 data.
# Message 686 (ID: Temperature_2) in 2022 data corresponds to message 212 in 2014 data.
# Message 687 (ID: Geopotential height_2) in 2022 data corresponds to message 279 in 2014 data.
# Message 688 (ID: Pressure_2) in 2022 data corresponds to message 280 in 2014 data.
# Message 689 (ID: 192_2) in 2022 data corresponds to message 281 in 2014 data.
# Message 690 (ID: u-component of wind_-2147481) in 2022 data corresponds to message 270 in 2014 data.
# Message 691 (ID: v-component of wind_-2147481) in 2022 data corresponds to message 271 in 2014 data.
# Message 692 (ID: Temperature_-2147481) in 2022 data corresponds to message 272 in 2014 data.
# Message 693 (ID: Geopotential height_-2147481) in 2022 data corresponds to message 273 in 2014 data.
# Message 694 (ID: Pressure_-2147481) in 2022 data corresponds to message 274 in 2014 data.
# Message 695 (ID: 192_-2147481) in 2022 data corresponds to message 275 in 2014 data.

# %%
with open('output.txt', 'w') as f:
    # 在2022年的FNL数据文件中查找与2014年相同ID的消息
    for i, id_2022 in enumerate(ids_2022):
        try:
            j = ids_2014.index(id_2022)
            # 如果找到相同ID的消息，则输出其位置和ID，并将结果写入文本文件中
            output = f"Message {i} (ID: {id_2022}) in 2022 data corresponds to message {j} in 2014 data.\n"
            f.write(output)
        except ValueError:
            # 如果未找到相同ID的消息，则输出警告，并将结果写入文本文件中
            output = f"Warning: Message {i} (ID: {id_2022}) in 2022 data has no corresponding message in 2014 data.\n"
            f.write(output)
