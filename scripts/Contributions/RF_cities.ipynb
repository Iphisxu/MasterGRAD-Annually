# %% [markdown]
# # 毕业论文`GRAD`
# ## 建立多元线性回归模型，定量评估影响
#
# *`Evan`*\
# *`2023-11-16`*
# ---

# %%
import numpy as np
import pandas as pd

import sys
sys.path.append('../../src/')
from namelist import *
from RandomForest import read_data, rf_importance

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
lowyears  = [2014,2015,2016]
highyears = [2019,2021,2022]
month     = 'Sep'
regions   = ['Zhaoqing','Huizhou','Guangzhou','Foshan',
             'Dongguan','Shenzhen','Zhongshan','Jiangmen',
             'Zhuhai']
datapath  = datadir + 'Contribution/data/'

# 设置变量列表和目标变量
variants = ['SFC_TMP', 'SOL_RAD', 'RH', 'PRES', 
            'WSPD10', 'WDIR10','CloudFRAC',
            'NO2', 'VOC', 'PM25', 'ISOP'] # 'PBLH',
target = 'O3'

# %% [markdown]
# ## 读取数据，建立模型

# %%
for region in regions:
    print(f'{region}\n')
    
    print('Reading data')
    df_low  = read_data(lowyears,month,region,datapath)
    df_high = read_data(highyears,month,region,datapath)

    print('Random Forest Modeling ...\n')
    low_importance = rf_importance(df_low,variants,target)
    print('\n===============================================\n')
    high_importance = rf_importance(df_high,variants,target)

    # 合并两组结果，对列重命名
    dfoutput = pd.concat([low_importance,high_importance],axis=1)
    dfoutput.columns=['Low','High']

    filepath = 'D:/data/Graduation/Contribution/RandomForest_output/TMP/'
    filename = f'RF_{region}.xlsx'
    dfoutput.to_excel(filepath + filename,index=True)
# Out:
# Zhaoqing
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 231.65407992846542
# R-squared (Random Forest): 0.8367354034736854
# NO2: 0.38273924839637763
# PM25: 0.12951627298480325
# SFC_TMP: 0.09353119526174329
# SOL_RAD: 0.08353486424913024
# WDIR10: 0.07454623933482572
# VOC: 0.05480517593642803
# ISOP: 0.053126735184855334
# RH: 0.03770740265859169
# CloudFRAC: 0.03293074073212307
# WSPD10: 0.03027412427271536
# PRES: 0.02728800098840617
#
# ===============================================
#
# Mean Squared Error (Random Forest): 144.70899032863883
# R-squared (Random Forest): 0.8844286065968553
# NO2: 0.3273241739261955
# RH: 0.15391974944872938
# SOL_RAD: 0.114671300804807
# SFC_TMP: 0.11411707339745814
# PM25: 0.08561149433300759
# VOC: 0.049401493110048184
# WDIR10: 0.04048387329831366
# PRES: 0.03571864733942737
# CloudFRAC: 0.033646020196897865
# WSPD10: 0.02318244303643256
# ISOP: 0.021923731108682943
# Huizhou
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 131.26586443357976
# R-squared (Random Forest): 0.9111830855245912
# PM25: 0.2115026515733441
# ISOP: 0.1422811946131401
# SFC_TMP: 0.1259607722420508
# SOL_RAD: 0.10896568512019296
# VOC: 0.08653965324525155
# RH: 0.08088517888780021
# NO2: 0.07016344238307239
# CloudFRAC: 0.06371259779629121
# WDIR10: 0.05743090686667646
# WSPD10: 0.028046599637925166
# PRES: 0.024511317634255042
#
# ===============================================
#
# Mean Squared Error (Random Forest): 110.45059408457409
# R-squared (Random Forest): 0.8980283730167132
# PM25: 0.2785463954003868
# RH: 0.21925898023215795
# SFC_TMP: 0.08540392500499028
# VOC: 0.08073646416839254
# SOL_RAD: 0.07674805474562842
# ISOP: 0.07139424598555723
# WSPD10: 0.052283637108161356
# WDIR10: 0.04852587440396696
# CloudFRAC: 0.03390314839794002
# NO2: 0.02798067301178408
# PRES: 0.02521860154103447
# Guangzhou
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 248.9373862988073
# R-squared (Random Forest): 0.9017299546822182
# SFC_TMP: 0.331585184815924
# SOL_RAD: 0.22788978442386423
# PM25: 0.07760804223425401
# RH: 0.06818778220291136
# VOC: 0.06697488308969808
# NO2: 0.06339373211852196
# WSPD10: 0.0522472827155312
# WDIR10: 0.03521300197682822
# CloudFRAC: 0.029441699196627223
# ISOP: 0.027328072974937414
# PRES: 0.020130534250902374
#
# ===============================================
#
# Mean Squared Error (Random Forest): 207.31794566851136
# R-squared (Random Forest): 0.9013102325046476
# SOL_RAD: 0.3972559989781841
# SFC_TMP: 0.1862394350066156
# PM25: 0.13969238241504567
# RH: 0.054293038660430254
# WSPD10: 0.04535568628818955
# VOC: 0.044691767836233236
# WDIR10: 0.04025062325819699
# NO2: 0.0252041571724799
# CloudFRAC: 0.024041518890028514
# PRES: 0.022554670772480048
# ISOP: 0.020420720722116224
# Foshan
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 434.6365089627099
# R-squared (Random Forest): 0.9022138843022335
# SOL_RAD: 0.5454919571379885
# PM25: 0.12140377728533473
# SFC_TMP: 0.0875765492525191
# RH: 0.0704546831746369
# WSPD10: 0.0479946563090883
# CloudFRAC: 0.037431544429581375
# NO2: 0.02642514262719109
# VOC: 0.018277124292473402
# WDIR10: 0.016931210931648188
# PRES: 0.014620771788075002
# ISOP: 0.013392582771463489
#
# ===============================================
#
# Mean Squared Error (Random Forest): 384.3268085479416
# R-squared (Random Forest): 0.9155057538138454
# NO2: 0.5645893109695713
# SFC_TMP: 0.1448887487946011
# VOC: 0.06744775195995908
# PM25: 0.06650349651092576
# WSPD10: 0.04192547440378011
# SOL_RAD: 0.03903051721317188
# CloudFRAC: 0.019235783320645083
# WDIR10: 0.01652586478418231
# ISOP: 0.0150021979159936
# RH: 0.013502297103346024
# PRES: 0.011348557023823728
# Dongguan
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 338.496979249928
# R-squared (Random Forest): 0.8995911505794826
# SOL_RAD: 0.44624456492815945
# PM25: 0.1343329439766306
# RH: 0.08379289650159331
# SFC_TMP: 0.06201784065670459
# NO2: 0.055639121001164034
# VOC: 0.050340185192425314
# WSPD10: 0.05000166438306691
# CloudFRAC: 0.045532159052209975
# WDIR10: 0.027812461637752136
# PRES: 0.02222818982489305
# ISOP: 0.022057972845400734
#
# ===============================================
#
# Mean Squared Error (Random Forest): 255.07606821239352
# R-squared (Random Forest): 0.9214311339405817
# SOL_RAD: 0.2793028394805429
# SFC_TMP: 0.2500698075442578
# PM25: 0.1388446921875415
# VOC: 0.10667339846381896
# WSPD10: 0.0697279262789831
# WDIR10: 0.04892173272397926
# NO2: 0.0401850173851747
# ISOP: 0.01963516536152698
# RH: 0.01940727660456433
# PRES: 0.01375845832230287
# CloudFRAC: 0.013473685647307729
# Shenzhen
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 222.2582847728643
# R-squared (Random Forest): 0.9306832155459441
# SOL_RAD: 0.31163619185789876
# PM25: 0.2555117508181954
# RH: 0.15398302811576794
# WSPD10: 0.08482594220257936
# SFC_TMP: 0.04131556346957354
# WDIR10: 0.03329784027768429
# VOC: 0.030748717259772747
# ISOP: 0.025226368101413987
# CloudFRAC: 0.024004360137927616
# NO2: 0.022731061644819507
# PRES: 0.016719176114366817
#
# ===============================================
#
# Mean Squared Error (Random Forest): 258.4769905916609
# R-squared (Random Forest): 0.9245120761206724
# PM25: 0.3938747746973732
# SOL_RAD: 0.24862777254785656
# SFC_TMP: 0.1396235020183474
# VOC: 0.050662251475508485
# WSPD10: 0.041977567381144845
# WDIR10: 0.038990209187889466
# NO2: 0.027516844175746683
# ISOP: 0.019490619742078778
# PRES: 0.014285313092572215
# RH: 0.013532896498965859
# CloudFRAC: 0.0114182491825165
# Zhongshan
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 328.76269805306146
# R-squared (Random Forest): 0.9279922026405646
# SOL_RAD: 0.42743958919685765
# PM25: 0.25574754479504447
# SFC_TMP: 0.08544266430527142
# NO2: 0.08152313260990991
# CloudFRAC: 0.027312144595377775
# WSPD10: 0.02697212781740627
# VOC: 0.02627197010852846
# RH: 0.021142311317253824
# WDIR10: 0.0179184049916443
# ISOP: 0.015985403069060645
# PRES: 0.014244707193645234
#
# ===============================================
#
# Mean Squared Error (Random Forest): 426.7064340872246
# R-squared (Random Forest): 0.9071456941791058
# SFC_TMP: 0.3494737156848855
# PM25: 0.27893464736093415
# SOL_RAD: 0.13682337208206308
# VOC: 0.07285028084931534
# NO2: 0.06713090641005906
# WSPD10: 0.021846697571909653
# PRES: 0.01790731047341628
# CloudFRAC: 0.01745650581671227
# ISOP: 0.013433335733303851
# WDIR10: 0.013365862603121408
# RH: 0.010777365414279465
# Jiangmen
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 177.8754803579933
# R-squared (Random Forest): 0.9453228332778589
# RH: 0.3573534248009301
# PM25: 0.2439379096344311
# SFC_TMP: 0.11973750405764058
# SOL_RAD: 0.10255120554548641
# NO2: 0.04514304534717075
# WDIR10: 0.031244110050542794
# CloudFRAC: 0.029664514014456113
# VOC: 0.024252221865938027
# PRES: 0.020147595568194933
# WSPD10: 0.013337180261401661
# ISOP: 0.012631288853807553
#
# ===============================================
#
# Mean Squared Error (Random Forest): 180.11213287161834
# R-squared (Random Forest): 0.9349003322407985
# PM25: 0.30000642707869185
# SOL_RAD: 0.2867453511142606
# SFC_TMP: 0.11123484964610886
# RH: 0.10425894138824147
# NO2: 0.06441083872600212
# VOC: 0.04357509812392432
# CloudFRAC: 0.026716080103834118
# WDIR10: 0.021082795718069074
# PRES: 0.017172220923905555
# WSPD10: 0.012867166997755013
# ISOP: 0.011930230179207019
# Zhuhai
#
# Reading data
# Random Forest Modeling ...
#
# Mean Squared Error (Random Forest): 348.92769147693826
# R-squared (Random Forest): 0.9092713645860641
# PM25: 0.3970769316089147
# NO2: 0.1499575820839832
# SOL_RAD: 0.13664064938887063
# SFC_TMP: 0.13440377059300718
# VOC: 0.040232403108974024
# RH: 0.03606524956316022
# WSPD10: 0.02515466782032626
# ISOP: 0.023202784681357926
# CloudFRAC: 0.022210189771153455
# WDIR10: 0.019701521384997787
# PRES: 0.015354249995254629
#
# ===============================================
#
# Mean Squared Error (Random Forest): 424.7791141411206
# R-squared (Random Forest): 0.8871411598892374
# PM25: 0.5192666305532203
# SOL_RAD: 0.2106743725957926
# SFC_TMP: 0.10333136301922197
# NO2: 0.061568273977889644
# VOC: 0.024012224626699896
# PRES: 0.015961748932622956
# RH: 0.01542190683640603
# WDIR10: 0.014544203724282471
# WSPD10: 0.014318805515052668
# ISOP: 0.013079768534971828
# CloudFRAC: 0.007820701683839817

# %% [markdown]
# ## 读取输出数据，整合到一张表中

# %%
infilepath = 'D:/data/Graduation/Contribution/RandomForest_output/TMP/'
outfilepath = 'D:/data/Graduation/Contribution/RandomForest_output/'
dfs = [infilepath + f'RF_{region}.xlsx' for region in regions]

writer = pd.ExcelWriter(outfilepath + 'RF_cities.xlsx', engine='xlsxwriter')
for region in regions:
    df = pd.read_excel(infilepath + f'RF_{region}.xlsx',index_col=0)
    sheet_name = region
    df.to_excel(writer, sheet_name=sheet_name,index=True)
writer.close()
